# %% [markdown]
# Run this cell until you get a tesla T4, if not go to runtime -> reset all runtimes and try utill you get one.

# %%
# !nvidia-smi
# Out:
# Thu Jun 20 11:40:29 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8    17W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Run this cell first to prepare your google drive

# %%
import os

# Load the Drive helper and mount
from google.colab import drive
# This will prompt for authorization.
drive.mount('/content/drive', force_remount=True)

# Create a folder to save the output
#if not os.path.isdir("/content/drive/My Drive/CodeTransformer"):
#  os.mkdir("/content/drive/My Drive/CodeTransformer")
#else:
#  print("Directory already exists, skipping...")
  
# Change working directory to this created folder
#os.chdir("/content/drive/My Drive/CodeTransformer")

# If the git does not exist, clone it, else open the folder
if not os.path.isdir("./Deep-Learning"):
  print("Initial clone of git repo...")
  # !git clone https://github.com/jverbraeken/Deep-Learning.git
  os.chdir("./Deep-Learning")
else:
  print("Folder exists, pulling git repo...")
  os.chdir("./Deep-Learning")
  # !git pull

# Create folders for Tensor2Tensor to operate in
if not os.path.isdir("./data"):
  print("Creating data folder...")
  os.mkdir("./data")

if not os.path.isdir("./tmp"):
  print("Creating tmp folder...")
  os.mkdir("./tmp")

if not os.path.isdir("./output"):
  print("Creating output folder...")
  os.mkdir("./output")
  
# Should print a list of folders and files from the git
# !ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Initial clone of git repo...
# Cloning into 'Deep-Learning'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 245 (delta 4), reused 8 (delta 4), pack-reused 234
# Receiving objects: 100% (245/245), 344.91 MiB | 44.45 MiB/s, done.
# Resolving deltas: 100% (106/106), done.
# Creating data folder...
# Creating tmp folder...
# Creating output folder...
# data		    output			 transformer
# data.7z		    prepare_transformer_data.py  transformer_data
# Evaluation	    preprocess			 transformer_preproc
# evaluation_scripts  readme.md
# models		    tmp

# %% [markdown]
# # (Optional) Load model from drive

# %%
# !unzip /content/drive/My\ Drive/model.zip
# Out:
# Archive:  /content/drive/My Drive/model.zip
#   inflating: output/events.out.tfevents.1558357928.be98dfc60ede
#   inflating: output/checkpoint
#   inflating: output/events.out.tfevents.1560017368.ce6872064321
#   inflating: output/model.ckpt-750000.data-00000-of-00002
#   inflating: output/flags.txt
#   inflating: output/events.out.tfevents.1559644271.ff9f4f4e3b5a
#    creating: output/eval/
#   inflating: output/eval/events.out.tfevents.1559567405.fc330bacea73
#   inflating: output/eval/events.out.tfevents.1559572781.fc330bacea73
#   inflating: output/eval/events.out.tfevents.1559644450.ff9f4f4e3b5a
#   inflating: output/eval/events.out.tfevents.1559553379.fc330bacea73
#   inflating: output/eval/events.out.tfevents.1560017547.ce6872064321
#   inflating: output/eval/events.out.tfevents.1559995182.ce6872064321
#   inflating: output/eval/events.out.tfevents.1558358117.be98dfc60ede
#   inflating: output/model.ckpt-750000.meta
#   inflating: output/events.out.tfevents.1559995000.ce6872064321
#   inflating: output/model.ckpt-750000.data-00001-of-00002
#   inflating: output/graph.pbtxt
#   inflating: output/model.ckpt-750000.index
#   inflating: output/hparams.json
#   inflating: output/events.out.tfevents.1559572595.fc330bacea73
#   inflating: output/events.out.tfevents.1559567224.fc330bacea73
#   inflating: output/flags_t2t.txt
#   inflating: output/events.out.tfevents.1559553203.fc330bacea73

# %% [markdown]
# # Run tensorboard

# %%
LOG_DIR = './output'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)
# Install
! npm install -g localtunnel

# Tunnel port 6006 (TensorBoard assumed running)
get_ipython().system_raw('lt --port 6006 >> url.txt 2>&1 &')
# Out:
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/client
# + localtunnel@1.9.1
# added 55 packages from 34 contributors in 3.531s

# %%
# !cat url.txt
# Out:
# your url is: https://afraid-firefox-3.localtunnel.me

# %% [markdown]
# # Run this cell to generate the data for the Transformer

# %%
# !t2t-datagen --t2t_usr_dir=./transformer_preproc --data_dir=./data --tmp_dir=./tmp --problem=code_transformer_preproc
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0620 11:46:54.899293 140593468053376 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/expert_utils.py:68: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 11:46:55.925122 140593468053376 deprecation_wrapper.py:119] From /usr/local/bin/t2t-datagen:27: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0620 11:46:55.925380 140593468053376 deprecation_wrapper.py:119] From /usr/local/bin/t2t-datagen:27: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W0620 11:46:55.925506 140593468053376 deprecation_wrapper.py:119] From /usr/local/bin/t2t-datagen:28: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0620 11:46:55.926088 140593468053376 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/usr_dir.py:42: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# I0620 11:46:55.926233 140593468053376 usr_dir.py:43] Importing user module transformer_preproc from path /content/Deep-Learning
# W0620 11:46:55.931682 140593468053376 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/bin/t2t_datagen.py:185: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# I0620 11:46:55.931911 140593468053376 t2t_datagen.py:189] Generating problems:
#     code:
#       * code_transformer_preproc
# W0620 11:46:55.932027 140593468053376 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/bin/t2t_datagen.py:140: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# I0620 11:46:55.940669 140593468053376 t2t_datagen.py:239] Generating data for code_transformer_preproc.
# :::MLPv0.5.0 transformer 1561031216.366911888 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/text_problems.py:306) preproc_tokenize_training
# I0620 11:46:56.366957 140593468053376 mlperf_log.py:156] :::MLPv0.5.0 transformer 1561031216.366911888 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/text_problems.py:306) preproc_tokenize_training
# W0620 11:46:56.367319 140593468053376 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/translate.py:133: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# W0620 11:46:56.367585 140593468053376 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/translate.py:137: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# I0620 11:46:56.367830 140593468053376 generator_utils.py:231] Downloading https://github.com/jverbraeken/Deep-Learning/blob/master/transformer_data/train_preproc.tgz?raw=true to ./tmp/train_preproc.tgz?raw=true
# W0620 11:46:56.367957 140593468053376 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/generator_utils.py:233: The name tf.gfile.Copy is deprecated. Please use tf.io.gfile.copy instead.
#
# 100% completed
# W0620 11:46:58.199443 140593468053376 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/generator_utils.py:241: The name tf.gfile.Rename is deprecated. Please use tf.io.gfile.rename instead.
#
# I0620 11:46:58.199820 140593468053376 generator_utils.py:246] Successfully downloaded train_preproc.tgz?raw=true, 75312383 bytes.
# I0620 11:47:09.129534 140593468053376 generator_utils.py:348] Generating vocab file: ./data/vocab.code_transformer_preproc.8192.subwords
# I0620 11:47:09.129945 140593468053376 generator_utils.py:371] Generating vocab from: [['https://github.com/jverbraeken/Deep-Learning/blob/master/transformer_data/train_preproc.tgz?raw=true', ('train/train.cd', 'train/train.en')]]
# I0620 11:47:09.130141 140593468053376 generator_utils.py:228] Not downloading, file already found: ./tmp/train_preproc.tgz?raw=true
# I0620 11:47:09.130228 140593468053376 generator_utils.py:378] Reading file: train/train.cd
# I0620 11:47:10.921734 140593468053376 generator_utils.py:378] Reading file: train/train.en
# I0620 11:47:12.018615 140593468053376 text_encoder.py:724] Trying min_count 500
# I0620 11:47:12.054835 140593468053376 text_encoder.py:804] Iteration 0
# I0620 11:47:13.632525 140593468053376 text_encoder.py:827] Processing token [zaosys5gm15khqzgs5ic9bjohhaoeru54zs7r2innc4cyutexqjxvjeivtvymsv8jvet3kenr0xtuvsqghmyuwslosafguwhjlr2urlozf1egjfwz2smo9rj3ajtrw3lvn8nngpd2evb9j6efbodxldoti03axilnqn0iiqomb8yomkm7ityvpemxj5myttcjropzaqi] took 0.165526866913 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0620 11:47:15.470447 140593468053376 text_encoder.py:827] Processing token [ - <\" + ] took 0.290671110153 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0620 11:47:18.320255 140593468053376 text_encoder.py:868] vocab_size = 1172
# I0620 11:47:18.320537 140593468053376 text_encoder.py:804] Iteration 1
# I0620 11
seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0620 11:50:32.949112 140593468053376 text_encoder.py:827] Processing token [ - <\" + ] took 0.211982965469 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0620 11:50:37.058427 140593468053376 text_encoder.py:868] vocab_size = 20443
# I0620 11:50:37.058726 140593468053376 text_encoder.py:804] Iteration 1
# I0620 11:50:40.009238 140593468053376 text_encoder.py:827] Processing token [ifkm0ijatoi41dozctfkygysjtz53xvvnm5tyzluispyymavdazenp6emc2ebfscmetgymdtdfvacdbjqhgnkkry5lbagwtubhqaokqfmz05q322n20hnpfk1egcybqlgmla] took 0.104318141937 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0620 11:50:41.512937 140593468053376 text_encoder.py:868] vocab_size = 7829
# I0620 11:50:41.513269 140593468053376 text_encoder.py:804] Iteration 2
# I0620 11:50:43.677336 140593468053376 text_encoder.py:827] Processing token [pj3pcv9wvt7c5bfwaqpzssqosk7hpnnjt4qfymn5u1c6ldik5idjdhohysvw04utmgmcesq6bmkhijf9fnnthjr8qrbpomolidnxqtxn741lswion2jbfdqr3] took 0.103802919388 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0620 11:50:45.507565 140593468053376 text_encoder.py:868] vocab_size = 8214
# I0620 11:50:45.507895 140593468053376 text_encoder.py:804] Iteration 3
# I0620 11:50:47.664047 140593468053376 text_encoder.py:827] Processing token [ \",\", \"+\", \"\"\", \"\\", \"<\", \">\", \";\" (] took 0.100517034531 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0620 11:50:49.495980 140593468053376 text_encoder.py:868] vocab_size = 8105
# W0620 11:50:50.169732 140593468053376 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/generator_utils.py:163: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# I0620 11:50:54.881263 140593468053376 generator_utils.py:169] Generating case 0.
# I0620 11:51:37.306086 140593468053376 generator_utils.py:169] Generating case 100000.
# I0620 11:52:18.145150 140593468053376 generator_utils.py:169] Generating case 200000.
# I0620 11:52:59.709876 140593468053376 generator_utils.py:169] Generating case 300000.
# I0620 11:53:39.924931 140593468053376 generator_utils.py:169] Generating case 400000.
# :::MLPv0.5.0 transformer 1561031647.142398119 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/text_problems.py:306) preproc_num_train_examples: 462824
# I0620 11:54:07.142448 140593468053376 mlperf_log.py:156] :::MLPv0.5.0 transformer 1561031647.142398119 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/text_problems.py:306) preproc_num_train_examples: 462824
# I0620 11:54:07.142819 140593468053376 generator_utils.py:192] Generated 462824 Examples
# :::MLPv0.5.0 transformer 1561031647.144236088 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/text_problems.py:306) preproc_tokenize_eval
# I0620 11:54:07.144260 140593468053376 mlperf_log.py:156] :::MLPv0.5.0 transformer 1561031647.144236088 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/text_problems.py:306) preproc_tokenize_eval
# I0620 11:54:07.144634 140593468053376 generator_utils.py:231] Downloading https://github.com/jverbraeken/Deep-Learning/blob/master/transformer_data/test_preproc.tgz?raw=true to ./tmp/test_preproc.tgz?raw=true
# 100% completed
# I0620 11:54:08.526160 140593468053376 generator_utils.py:246] Successfully downloaded test_preproc.tgz?raw=true, 8501595 bytes.
# I0620 11:54:09.801414 140593468053376 generator_utils.py:343] Found vocab file: ./data/vocab.code_transformer_preproc.8192.subwords
# I0620 11:54:10.466172 140593468053376 generator_utils.py:169] Generating case 0.
# :::MLPv0.5.0 transformer 1561031671.923852921 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/text_problems.py:306) preproc_num_eval_examples: 58655
# I0620 11:54:31.923897 140593468053376 mlperf_log.py:156] :::MLPv0.5.0 transformer 1561031671.923852921 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/text_problems.py:306) preproc_num_eval_examples: 58655
# I0620 11:54:31.924236 140593468053376 generator_utils.py:192] Generated 58655 Examples
# I0620 11:54:31.925458 140593468053376 generator_utils.py:510] Shuffling data...
# W0620 11:54:31.925679 140593468053376 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators
train-00032-of-00100', './data/code_transformer_preproc-unshuffled-train-00033-of-00100', './data/code_transformer_preproc-unshuffled-train-00034-of-00100', './data/code_transformer_preproc-unshuffled-train-00035-of-00100', './data/code_transformer_preproc-unshuffled-train-00036-of-00100', './data/code_transformer_preproc-unshuffled-train-00037-of-00100', './data/code_transformer_preproc-unshuffled-train-00038-of-00100', './data/code_transformer_preproc-unshuffled-train-00039-of-00100', './data/code_transformer_preproc-unshuffled-train-00040-of-00100', './data/code_transformer_preproc-unshuffled-train-00041-of-00100', './data/code_transformer_preproc-unshuffled-train-00042-of-00100', './data/code_transformer_preproc-unshuffled-train-00043-of-00100', './data/code_transformer_preproc-unshuffled-train-00044-of-00100', './data/code_transformer_preproc-unshuffled-train-00045-of-00100', './data/code_transformer_preproc-unshuffled-train-00046-of-00100', './data/code_transformer_preproc-unshuffled-train-00047-of-00100', './data/code_transformer_preproc-unshuffled-train-00048-of-00100', './data/code_transformer_preproc-unshuffled-train-00049-of-00100', './data/code_transformer_preproc-unshuffled-train-00050-of-00100', './data/code_transformer_preproc-unshuffled-train-00051-of-00100', './data/code_transformer_preproc-unshuffled-train-00052-of-00100', './data/code_transformer_preproc-unshuffled-train-00053-of-00100', './data/code_transformer_preproc-unshuffled-train-00054-of-00100', './data/code_transformer_preproc-unshuffled-train-00055-of-00100', './data/code_transformer_preproc-unshuffled-train-00056-of-00100', './data/code_transformer_preproc-unshuffled-train-00057-of-00100', './data/code_transformer_preproc-unshuffled-tr ...
# :::MLPv0.5.0 transformer 1560241196.067579985 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/text_problems.py:306) preproc_tokenize_eval
# INFO:tensorflow:Downloading https://github.com/jverbraeken/Deep-Learning/blob/master/transformer_data/test_preproc.tgz?raw=true to /tmp/t2t_datagen/test_preproc.tgz?raw=true
# 100% completed
# INFO:tensorflow:Successfully downloaded test_preproc.tgz?raw=true, 8501595 bytes.
# INFO:tensorflow:Found vocab file: ./data/vocab.code_transformer_preproc.8192.subwords
# INFO:tensorflow:Skipping generator because outputs files exists at ['./data/code_transformer_preproc-unshuffled-dev-00000-of-00001']
# INFO:tensorflow:Skipping shuffle because output files exist
# INFO:tensorflow:Loading hparams from existing json ./output/hparams.json
# INFO:tensorflow:Overwrite key batch_size: 2048 -> 1024
# INFO:tensorflow:Overriding hparams in transformer_base_single_gpu with batch_size=1024
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/trainer_lib.py:278: __init__ (from tensorflow.contrib.learn.python.learn.estimators.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.RunConfig instead.
# INFO:tensorflow:Configuring DataParallelism to replicate the model.
# INFO:tensorflow:schedule=continuous_train_and_eval
# INFO:tensorflow:worker_gpu=1
# INFO:tensorflow:sync=False
# WARNING:tensorflow:Schedule=continuous_train_and_eval. Assuming that training is running on a single machine.
# INFO:tensorflow:datashard_devices: ['gpu:0']
# INFO:tensorflow:caching_devices: None
# INFO:tensorflow:ps_devices: ['gpu:0']
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': None, '_num_ps_replicas': 0, '_keep_checkpoint_max': 1, '_task_type': None, '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f2744fd4150>, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_protocol': None, '_save_checkpoints_steps': 1000, '_keep_checkpoint_every_n_hours': 10000, '_session_config': gpu_options {
#   per_process_gpu_memory_fraction: 0.95
# }
# allow_soft_placement: true
# graph_options {
#   optimizer_options {
#     global_jit_level: OFF
#   }
# }
# , '_model_dir': './output', 'use_tpu': False, '_tf_random_seed': None, '_master': '', '_device_fn': None, '_num_worker_replicas': 0, '_task_id': 0, '_log_step_count_steps': 100, '_evaluation_master': '', '_eval_distribute': None, 'data_parallelism': <tensor2tensor.utils.expert_utils.Parallelism object at 0x7f2744fd4190>, '_environment': 'local', '_save_summary_steps': 100, 't2t_device_info': {'num_async_replicas': 1}}
# WARNING:tensorflow:Estimator's model_fn (<function wrapping_model_fn at 0x7f2744fb62a8>) includes params argument, but params are not passed to Estimator.
# WARNING:tensorflow:ValidationMonitor only works with --schedule=train_and_evaluate
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1000 or save_checkpoints_secs None.
# INFO:tensorflow:Skipping training since max_steps has already saved.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# :::MLPv0.5.0 transformer 1560241199.669811010 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/problem.py:759) input_max_length: 256
# INFO:tensorflow:Reading data files from ./data/code_transformer_preproc-dev*
# INFO:tensorflow:partition: 0 num_data_files: 1
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/data_reader.py:31: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/problem.py:947: bucket_by_sequence_length (from tensorflow.contrib.data.python.ops.grouping) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.bucket_by_sequence_length(...)`.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/problem.py:1211: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Calling model_fn.
# :::MLPv0.5.0 transformer 1560241200.365704060 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:59) model_hp_embedding_shared_weights: {"vocab_size": 8105, "hidden_size": 512}
# INFO:tensorflow:Setting T2TModel mode to 'eval'
# INFO:tensorflow:Setting hparams.layer_prepostprocess_dropout to 0.0
# INFO:tensorflow:Setting hparams.symbol_dropout to 0.0
# INFO:tensorflow:Setting hparams.label_smoothing to 0.0
# INFO:tensorflow:Setting hparams.attention_dropout to 0.0
# INFO:tensorflow:Setting hparams.dropout to 0.0
# INFO:tensorflow:Setting hparams.relu_dropout to 0.0
# :::MLPv0.5.0 transformer 1560241200.452867031 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/t2t_model.py:228) model_hp_initializer_gain: 1.0
# INFO:tensorflow:Using variable initializer: uniform_unit_scaling
# INFO:tensorflow:Transforming feature 'inputs' with symbol_modality_8105_512.bottom
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/function.py:1007: calling create_op (from tensorflow.python.framework.ops) with compute_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# Shapes are always computed; don't use the compute_shapes as it has no effect.
# INFO:tensorflow:Transforming feature 'targets' with symbol_modality_8105_512.targets_bottom
# INFO:tensorflow:Building model body
# :::MLPv0.5.0 transformer 1560241201.001748085 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:186) model_hp_layer_postprocess_dropout: 0.0
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:92: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# :::MLPv0.5.0 transformer 1560241201.003257036 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:101) model_hp_hidden_layers: 6
# :::MLPv0.5.0 transformer 1560241201.004185915 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:101) model_hp_attention_dropout: 0.0
# :::MLPv0.5.0 transformer 1560241201.005121946 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:101) model_hp_attention_dense: {"num_heads": 8, "use_bias": "false", "hidden_size": 512}
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/common_layers.py:2926: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# :::MLPv0.5.0 transformer 1560241201.238297939 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_ffn_filter_dense: {"filter_size": 2048, "activation": "relu", "use_bias": "True"}
# :::MLPv0.5.0 transformer 1560241201.239332914 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_ffn_output_dense: {"use_bias": "True", "hidden_size": 512}
# :::MLPv0.5.0 transformer 1560241201.240261078 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_relu_dropout: 0.0
# :::MLPv0.5.0 transformer 1560241201.540138006 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_ffn_filter_dense: {"filter_size": 2048, "activation": "relu", "use_bias": "True"}
# :::MLPv0.5.0 transformer 1560241201.541099072 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_ffn_output_dense: {"use_bias": "True", "hidden_size": 512}
# :::MLPv0.5.0 transformer 1560241201.542013884 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_relu_dropout: 0.0
# :::MLPv0.5.0 transformer 1560241202.070552111 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_ffn_filter_dense: {"filter_size": 2048, "activation": "relu", "use_bias": "True"}
# :::MLPv0.5.0 transformer 1560241202.071599007 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_ffn_output_dense: {"use_bias": "True", "hidden_size": 512}
# :::MLPv0.5.0 transformer 1560241202.072504044 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_relu_dropout: 0.0
# :::MLPv0.5.0 transformer 1560241202.370464087 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_ffn_filter_dense: {"filter_size": 2048, "activation": "relu", "use_bias": "True"}
# :::MLPv0.5.0 transformer 1560241202.371471882 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_ffn_output_dense: {"use_bias": "True", "hidden_size": 512}
# :::MLPv0.5.0 transformer 1560241202.372395992 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_relu_dropout: 0.0
# :::MLPv0.5.0 transformer 1560241202.664560080 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_ffn_filter_dense: {"filter_size": 2048, "activation": "relu", "use_bias": "True"}
# :::MLPv0.5.0 transformer 1560241202.665914059 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_ffn_output_dense: {"use_bias": "True", "hidden_size": 512}
# :::MLPv0.5.0 transformer 1560241202.666832924 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_relu_dropout: 0.0
# :::MLPv0.5.0 transformer 1560241202.960925102 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_ffn_filter_dense: {"filter_size": 2048, "activation": "relu", "use_bias": "True"}
# :::MLPv0.5.0 transformer 1560241202.961918116 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_ffn_output_dense: {"use_bias": "True", "hidden_size": 512}
# :::MLPv0.5.0 transformer 1560241202.962835073 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/transformer_layers.py:188) model_hp_relu_dropout: 0.0
# :::MLPv0.5.0 transformer 1560241203.312455893 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:101) model_hp_norm: {"hidden_size": 512}
# :::MLPv0.5.0 transformer 1560241203.408418894 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:202) model_hp_layer_postprocess_dropout: 0.0
# :::MLPv0.5.0 transformer 1560241203.409562111 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:153) model_hp_hidden_layers: 6
# :::MLPv0.5.0 transformer 1560241203.410485029 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:153) model_hp_attention_dropout: 0.0
# :::MLPv0.5.0 transformer 1560241203.411358118 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:153) model_hp_attention_dense: {"num_heads": 8, "use_bias": "false", "hidden_size": 512}
# :::MLPv0.5.0 transformer 1560241203.811908007 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_ffn_filter_dense: {"filter_size": 2048, "activation": "relu", "use_bias": "True"}
# :::MLPv0.5.0 transformer 1560241203.812923908 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_ffn_output_dense: {"use_bias": "True", "hidden_size": 512}
# :::MLPv0.5.0 transformer 1560241203.813836098 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_relu_dropout: 0.0
# :::MLPv0.5.0 transformer 1560241204.286717892 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_ffn_filter_dense: {"filter_size": 2048, "activation": "relu", "use_bias": "True"}
# :::MLPv0.5.0 transformer 1560241204.287790060 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_ffn_output_dense: {"use_bias": "True", "hidden_size": 512}
# :::MLPv0.5.0 transformer 1560241204.288726091 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_relu_dropout: 0.0
# :::MLPv0.5.0 transformer 1560241205.048501015 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_ffn_filter_dense: {"filter_size": 2048, "activation": "relu", "use_bias": "True"}
# :::MLPv0.5.0 transformer 1560241205.049640894 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_ffn_output_dense: {"use_bias": "True", "hidden_size": 512}
# :::MLPv0.5.0 transformer 1560241205.050586939 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_relu_dropout: 0.0
# :::MLPv0.5.0 transformer 1560241205.525465965 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_ffn_filter_dense: {"filter_size": 2048, "activation": "relu", "use_bias": "True"}
# :::MLPv0.5.0 transformer 1560241205.526499033 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_ffn_output_dense: {"use_bias": "True", "hidden_size": 512}
# :::MLPv0.5.0 transformer 1560241205.527436972 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_relu_dropout: 0.0
# :::MLPv0.5.0 transformer 1560241205.992249012 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_ffn_filter_dense: {"filter_size": 2048, "activation": "relu", "use_bias": "True"}
# :::MLPv0.5.0 transformer 1560241205.993273020 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_ffn_output_dense: {"use_bias": "True", "hidden_size": 512}
# :::MLPv0.5.0 transformer 1560241205.994185925 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_relu_dropout: 0.0
# :::MLPv0.5.0 transformer 1560241206.801377058 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_ffn_filter_dense: {"filter_size": 2048, "activation": "relu", "use_bias": "True"}
# :::MLPv0.5.0 transformer 1560241206.802432060 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_ffn_output_dense: {"use_bias": "True", "hidden_size": 512}
# :::MLPv0.5.0 transformer 1560241206.803375006 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_relu_dropout: 0.0
# :::MLPv0.5.0 transformer 1560241206.867108107 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:153) model_hp_norm: {"hidden_size": 512}
# INFO:tensorflow:Transforming body output with symbol_modality_8105_512.top
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/bleu_hook.py:151: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, use
#     tf.py_function, which takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-11T08:20:07Z
# INFO:tensorflow:Graph was finalized.
# 2019-06-11 08:20:09.452357: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-06-11 08:20:09.452811: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x562f4565bc80 executing computations on platform Host. Devices:
# 2019-06-11 08:20:09.452849: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-06-11 08:20:09.713953: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-11 08:20:09.714523: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x562f4565a680 executing computations on platform CUDA. Devices:
# 2019-06-11 08:20:09.714556: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2019-06-11 08:20:09.714971: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# totalMemory: 14.73GiB freeMemory: 14.60GiB
# 2019-06-11 08:20:09.714997: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-06-11 08:20:10.985887: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-11 08:20:10.985968: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-06-11 08:20:10.985993: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-06-11 08:20:10.986281: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-06-11 08:20:10.986372: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14325 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./output/model.ckpt-750000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 2019-06-11 08:20:14.879954: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-11-08:20:48
# INFO:tensorflow:Saving dict for global step 750000: global_step = 750000, loss = 3.3024383, metrics-code_transformer_preproc/targets/accuracy = 0.4447209, metrics-code_transformer_preproc/targets/accuracy_per_sequence = 0.023839397, metrics-code_transformer_preproc/targets/accuracy_top5 = 0.64815015, metrics-code_transformer_preproc/targets/approx_bleu_score = 0.08184219, metrics-code_transformer_preproc/targets/neg_log_perplexity = -3.2195003, metrics-code_transformer_preproc/targets/rouge_2_fscore = 0.17297117, metrics-code_transformer_preproc/targets/rouge_L_fscore = 0.21386807
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 750000: ./output/model.ckpt-750000
# :::MLPv0.5.0 transformer 1560241248.452413082 (/usr/local/bin/t2t-trainer:28) run_final

# %% [markdown]
# # Upload trained model to drive

# %%
#import shutil
#!zip -r ./model.zip ./output
shutil.move("./model.zip", "/content/drive/My Drive")
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls -lh
# Out:
# total 57M
# drwxr-xr-x 2 root root  16K Jun  8 11:55 data
# -rw-r--r-- 1 root root  57M Jun  8 11:45 data.7z
# drwxr-xr-x 3 root root 4.0K Jun  8 11:45 Evaluation
# drwxr-xr-x 2 root root 4.0K Jun  8 11:45 evaluation_scripts
# drwxr-xr-x 2 root root 4.0K Jun  8 11:45 models
# drwxr-xr-x 3 root root 4.0K Jun  8 19:19 output
# -rw-r--r-- 1 root root 1.8K Jun  8 11:45 prepare_transformer_data.py
# drwxr-xr-x 2 root root 4.0K Jun  8 11:45 preprocess
# -rw-r--r-- 1 root root  112 Jun  8 11:45 readme.md
# drwxr-xr-x 4 root root 4.0K Jun  8 11:55 tmp
# drwxr-xr-x 2 root root 4.0K Jun  8 11:45 transformer
# drwxr-xr-x 2 root root 4.0K Jun  8 11:45 transformer_data
# drwxr-xr-x 2 root root 4.0K Jun  8 11:48 transformer_preproc

# %% [markdown]
# # Run decoder

# %%
# !t2t-decoder --t2t_usr_dir=./transformer_preproc --data_dir=./data --output_dir=./output --problem=code_transformer_preproc --model=transformer --hparams_set=transformer_base_single_gpu --hparams='batch_size=1024' --decode_hparams="beam_size=4,alpha=0.6" --decode_from_file="./sampled.cd" --decode_to_file="./sampled_model.en"
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0620 11:55:33.079386 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/expert_utils.py:68: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 11:55:33.809160 139711288199040 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0620 11:55:35.692384 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/adafactor.py:27: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0620 11:55:35.694138 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/multistep_optimizer.py:32: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0620 11:55:35.722929 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/mesh_tensorflow/ops.py:4237: The name tf.train.CheckpointSaverListener is deprecated. Please use tf.estimator.CheckpointSaverListener instead.
#
# W0620 11:55:35.723193 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/mesh_tensorflow/ops.py:4260: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W0620 11:55:35.880666 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/trainer_lib.py:105: The name tf.OptimizerOptions is deprecated. Please use tf.compat.v1.OptimizerOptions instead.
#
# W0620 11:55:36.459364 139711288199040 deprecation_wrapper.py:119] From /usr/local/bin/t2t-decoder:16: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0620 11:55:36.459635 139711288199040 deprecation_wrapper.py:119] From /usr/local/bin/t2t-decoder:16: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W0620 11:55:36.459783 139711288199040 deprecation_wrapper.py:119] From /usr/local/bin/t2t-decoder:17: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0620 11:55:36.460375 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/trainer_lib.py:789: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# W0620 11:55:36.461604 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/usr_dir.py:42: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# I0620 11:55:36.461762 139711288199040 usr_dir.py:43] Importing user module transformer_preproc from path /content/Deep-Learning
# I0620 11:55:36.462438 139711288199040 trainer_lib.py:148] Overriding hparams in transformer_base_single_gpu with batch_size=1024
# W0620 11:55:36.462893 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/text_encoder.py:940: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# W0620 11:55:36.463093 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/text_encoder.py:942: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0620 11:55:36.522059 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/trainer_lib.py:117: The name tf.GraphOptions is deprecated. Please use tf.compat.v1.GraphOptions instead.
#
# W0620 11:55:36.522397 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/trainer_lib.py:123: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# W0620 11:55:36.522675 139711288199040 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/trainer_lib.py:278: __init__ (from tensorflow.contrib.learn.python.learn.estimators.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.RunConfig instead.
# I0620 11:55:36.523267 139711288199040 trainer_lib.py:301] Configuring DataParallelism to replicate the model.
# I0620 11:55:36.523413 139711288199040 devices.py:76] schedule=continuous_train_and_eval
# I0620 11:55:36.523518 139711288199040 devices.py:77] worker_gpu=1
# I0620 11:55:36.523617 139711288199040 devices.py:78] sync=False
# W0620 11:55:36.523767 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/devices.py:139: The name tf.logging.warn is deprecated. Please use tf.compat.v1.logging.warn instead.
#
# W0620 11:55:36.523890 139711288199040 devices.py:141] Schedule=continuous_train_and_eval. Assuming that training is running on a single machine.
# I0620 11:55:36.524665 139711288199040 devices.py:170] datashard_devices: ['gpu:0']
# I0620 11:55:36.524813 139711288199040 devices.py:171] caching_devices: None
# I0620 11:55:36.525419 139711288199040 devices.py:172] ps_devices: ['gpu:0']
# I0620 11:55:36.526326 139711288199040 estimator.py:209] Using config: {'_save_checkpoints_secs': None, '_num_ps_replicas': 0, '_keep_checkpoint_max': 20, '_task_type': None, '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f10c547a490>, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_protocol': None, '_save_checkpoints_steps': 1000, '_keep_checkpoint_every_n_hours': 10000, '_session_config': gpu_options {
#   per_process_gpu_memory_fraction: 0.95
# }
# allow_soft_placement: true
# graph_options {
#   optimizer_options {
#     global_jit_level: OFF
#   }
# }
# , '_model_dir': './output', 'use_tpu': False, '_tf_random_seed': None, '_master': '', '_device_fn': None, '_num_worker_replicas': 0, '_task_id': 0, '_log_step_count_steps': 100, '_experimental_max_worker_delay_secs': None, '_evaluation_master': '', '_eval_distribute': None, 'data_parallelism': <tensor2tensor.utils.expert_utils.Parallelism object at 0x7f10c547a4d0>, '_environment': 'local', '_save_summary_steps': 100, 't2t_device_info': {'num_async_replicas': 1}}
# W0620 11:55:36.526603 139711288199040 model_fn.py:630] Estimator's model_fn (<function wrapping_model_fn at 0x7f10c5d679b0>) includes params argument, but params are not passed to Estimator.
# I0620 11:55:36.527621 139711288199040 decoding.py:353] decode_hp.batch_size not specified; default=32
# I0620 11:55:36.527781 139711288199040 decoding.py:364] Performing decoding from file (./sampled.cd).
# I0620 11:55:36.527879 139711288199040 decoding.py:731] Getting sorted inputs
# I0620 11:55:36.555919 139711288199040 decoding.py:580]  batch 16
# I0620 11:55:36.556061 139711288199040 decoding.py:585] Decoding batch 0
# W0620 11:55:36.572861 139711288199040 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/decoding.py:525: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0620 11:55:36.576211 139711288199040 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/decoding.py:821: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0620 11:55:36.583024 139711288199040 estimator.py:1000] Input graph does not use tf.data.Dataset or contain a QueueRunner. That means predict yields forever. This is probably a mistake.
# I0620 11:55:36.583388 139711288199040 estimator.py:1145] Calling model_fn.
# :::MLPv0.5.0 transformer 1561031737.426423073 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:59) model_hp_embedding_shared_weights: {"vocab_size": 8105, "hidden_size": 512}
# I0620 11:55:37.426490 139711288199040 mlperf_log.py:156] :::MLPv0.5.0 transformer 1561031737.426423073 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:59) model_hp_embedding_shared_weights: {"vocab_size": 8105, "hidden_size": 512}
# I0620 11:55:37.426872 139711288199040 t2t_model.py:1905] Setting T2TModel mode to 'infer'
# I0620 11:55:37.427189 139711288199040 t2t_model.py:1905] Setting hparams.layer_prepostprocess_dropout to 0.0
# I0620 11:55:37.427301 139711288199040 t2t_model.py:1905] Setting hparams.symbol_dropout to 0.0
# I0620 11:55:37.427393 139711288199040 t2t_model.py:1905] Setting hparams.label_smoothing to 0.0
# I0620 11:55:37.427480 139711288199040 t2t_model.py:1905] Setting hparams.attention_dropout to 0.0
# I0620 11:55:37.427556 139711288199040 t2t_model.py:1905] Setting hparams.dropout to 0.0
# I0620 11:55:37.427639 139711288199040 t2t_model.py:1905] Setting hparams.relu_dropout to 0.0
# W0620 11:55:37.481487 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/t2t_model.py:167: The name tf.summary.text is deprecated. Please use tf.compat.v1.summary.text instead.
#
# I0620 11:55:37.495134 139711288199040 t2t_model.py:1905] Beam Decoding with beam size 4
# W0620 11:55:37.654301 139711288199040 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/layers/modalities.py:114: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0620 11:55:37.677350 139711288199040 deprecation.py:506] From /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling __init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# :::MLPv0.5.0 transformer 1561031737.770721912 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/expert_utils.py:231) model_hp_layer_postprocess_dropout: 0.0
# I0620 11:55:37.770764 139711288199040 mlperf_log.py:156] :::MLPv0.5.0 transformer 1561031737.770721912 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/expert_utils.py:231) model_hp_layer_postprocess_dropout: 0.0
# W0620 11:55:37.771070 139711288199040 deprecation.py:506] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:92: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# :::MLPv0.5.0 transformer 1561031737.772321939 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:101) model_hp_hidden_layers: 6
# I0620 11:55:37.772342 139711288199040 mlperf_log.py:156] :::MLPv0.5.0 transformer 1561031737.772321939 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:101) model_hp_hidden_layers: 6
# :::MLPv0.5.0 transformer 1561031737.773247957 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:101) model_hp_attention_
(/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:1295) model_hp_relu_dropout: 0.0
# :::MLPv0.5.0 transformer 1561031744.766460896 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:153) model_hp_norm: {"hidden_size": 512}
# I0620 11:55:44.766504 139711288199040 mlperf_log.py:156] :::MLPv0.5.0 transformer 1561031744.766460896 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/models/transformer.py:153) model_hp_norm: {"hidden_size": 512}
# W0620 11:55:45.324525 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/t2t_model.py:1905: The name tf.logging.debug is deprecated. Please use tf.compat.v1.logging.debug instead.
#
# W0620 11:55:45.324917 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/t2t_model.py:1566: The name tf.saved_model.signature_constants.DEFAULT_SERVING_SIGNATURE_DEF_KEY is deprecated. Please use tf.saved_model.DEFAULT_SERVING_SIGNATURE_DEF_KEY instead.
#
# I0620 11:55:45.325253 139711288199040 estimator.py:1147] Done calling model_fn.
# I0620 11:55:46.200193 139711288199040 monitored_session.py:240] Graph was finalized.
# 2019-06-20 11:55:46.215388: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-06-20 11:55:46.216038: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55c801437c00 executing computations on platform Host. Devices:
# 2019-06-20 11:55:46.216097: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-06-20 11:55:46.235795: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-06-20 11:55:46.503791: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-20 11:55:46.504478: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55c801437f80 executing computations on platform CUDA. Devices:
# 2019-06-20 11:55:46.504514: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2019-06-20 11:55:46.504950: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-20 11:55:46.505358: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2019-06-20 11:55:46.524554: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-06-20 11:55:46.679660: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-06-20 11:55:46.753827: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2019-06-20 11:55:46.773499: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2019-06-20 11:55:46.942641: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2019-06-20 11:55:47.046214: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2019-06-20 11:55:47.376349: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-06-20 11:55:47.376723: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-20 11:55:47.377307: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-20 11:55:47.377722: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2019-06-20 11:55:47.380843: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-06-20 11:55:47.382375: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-20 11:55:47.382412: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2019-06-20 11:55:47.382435: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2019-06-20 11:55:47.384878: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-20 11:55:47.385391: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-20 11:55:47.385777: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:40] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-06-20 11:55:47.385835: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14325 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# W0620 11:55:47.386599 139711288199040 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# I0620 11:55:47.388762 139711288199040 saver.py:1280] Restoring parameters from ./output/model.ckpt-750000
# 2019-06-20 11:55:49.934787: W tensorflow/compiler/jit/mark_for_compilation_pass.cc:1412] (One-time warning): Not using XLA:CPU for cluster because envvar TF_XLA_FLAGS=--tf_xla_cpu_global_jit was not set.  If you want XLA:CPU, either set that envvar, or use experimental_jit_scope to enable XLA:CPU.  To confirm that XLA is active, pass --vmodule=xla_compilation_cache=1 (as a proper command-line flag, not via TF_XLA_FLAGS) or set the envvar XLA_FLAGS=--xla_hlo_profile.
# I0620 11:55:49.969146 139711288199040 session_manager.py:500] Running local_init_op.
# I0620 11:55:50.066956 139711288199040 session_manager.py:502] Done running local_init_op.
# 2019-06-20 11:55:52.559217: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# I0620 11:56:17.960341 139711288199040 decoding.py:136] Inference results INPUT: public static Mp4BoxHeader seekWithinLevel(ByteBuffer data,String id) throws IOException {\n  logger.finer(\"Started searching for:\" + id + \" in bytebuffer at\"+ data.position());\n  Mp4BoxHeader boxHeader=new Mp4BoxHeader();\n  if (data.remaining() >= Mp4BoxHeader.HEADER_LENGTH) {\n    boxHeader.update(data);\n  }\n else {\n    return null;\n  }\n  while (!boxHeader.getId().equals(id)) {\n    logger.finer(\"Found:\" + boxHeader.getId() + \" Still searching for:\"+ id+ \" in bytebuffer at\"+ data.position());\n    if (boxHeader.getLength() < Mp4BoxHeader.HEADER_LENGTH) {\n      return null;\n    }\n    if (data.remaining() < (boxHeader.getLength() - HEADER_LENGTH)) {\n      return null;\n    }\n    data.position(data.position() + (boxHeader.getLength() - HEADER_LENGTH));\n    if (data.remaining() >= Mp4BoxHeader.HEADER_LENGTH) {\n      boxHeader.update(data);\n    }\n else {\n      return null;\n    }\n  }\n  logger.finer(\"Found:\" + id + \" in bytebuffer at\"+ data.position());\n  return boxHeader;\n}\n
# I0620 11:56:17.960853 139711288199040 decoding.py:151] Inference results OUTPUT: Performs a bin search.
# I0620 11:56:17.962471 139711288199040 decoding.py:136] Inference results INPUT: @Override public boolean equals(Object obj){\n  if (obj == null) {\n    return false;\n  }\n  if (!getClass().equals(obj.getClass())) {\n    return false;\n  }\n  StaticAttributes object=(StaticAttributes)obj;\n  if (propertyName == null) {\n    if (object.propertyName != null) {\n      return false;\n    }\n  }\n else {\n    if (!propertyName.equals(object.propertyName)) {\n      return false;\n    }\n  }\n  if (propertyValues == null) {\n    if (object.propertyValues != null) {\n      return false;\n    }\n  }\n else {\n    if (!propertyValues.equals(object.propertyValues)) {\n      return false;\n    }\n  }\n  if (pResponseProviderName == null) {\n    if (object.getPResponseProviderName() != null) {\n      return false;\n    }\n  }\n else {\n    if (!pResponseProviderName.equals(object.getPResponseProviderName())) {\n      return false;\n    }\n  }\n  return true;\n}\n
# I0620 11:56:17.962707 139711288199040 decoding.py:151] Inference results OUTPUT: Tests this instance for equality with an arbitrary object.
# I0620 11:56:17.964859 139711288199040 decoding.py:136] Inference results INPUT: @Override protected void service(HttpServletRequest req,HttpServletResponse resp) throws ServletException, IOException {\n  final String path=getRelativePath(req);\n  if (isSpecialPath(path)) {\n    resp.sendError(WebdavStatus.SC_NOT_FOUND);\n    return;\n  }\n  final String method=req.getMethod();\n  if (debug > 0) {\n    log(\"[\" + method + \"] \"+ path);\n  }\n  if (method.equals(METHOD_PROPFIND)) {\n    doPropfind(req,resp);\n  }\n else   if (method.equals(METHOD_PROPPATCH)) {\n    doProppatch(req,resp);\n  }\n else   if (method.equals(METHOD_MKCOL)) {\n    doMkcol(req,resp);\n  }\n else   if (method.equals(METHOD_COPY)) {\n    doCopy(req,resp);\n  }\n else   if (method.equals(METHOD_MOVE)) {\n    doMove(req,resp);\n  }\n else   if (method.equals(METHOD_LOCK)) {\n    doLock(req,resp);\n  }\n else   if (method.equals(METHOD_UNLOCK)) {\n    doUnlock(req,resp);\n  }\n else {\n    super.service(req,resp);\n  }\n}\n
# I0620 11:56:17.965137 139711288199040 decoding.py:151] Inference results OUTPUT: Perform an \"svn remove\" based on the request.
# I0620 11:56:17.966674 139711288199040 decoding.py:136] Inference results INPUT: @Override public boolean equals(Object o){\n  rwlock.readLock().lock();\n  try {\n    if (o == this) {\n      return true;\n    }\n    if (!(o instanceof Map)) {\n      return false;\n    }\n    Map t=(Map)o;\n    if (t.size() != size()) {\n      return false;\n    }\n    for (Iterator i=entrySet().iterator(); i.hasNext(); ) {\n      Entry e=(Entry)i.next();\n      Object key=e.getKey();\n      Object value=e.getValue();\n      if (value == null) {\n        if (!(t.get(key) == null && t.containsKey(key))) {\n          return false;\n        }\n      }\n else {\n        if (!value.equals(t.get(key))) {\n          return false;\n        }\n      }\n    }\n    return true;\n  }\n  finally {\n    rwlock.readLock().unlock();\n  }\n}\n
# I0620 11:56:17.966941 139711288199040 decoding.py:151] Inference results OUTPUT: Compares this map with another map for equality of their stored entries.
# I0620 11:56:17.968436 139711288199040 decoding.py:136] Inference results INPUT: public static boolean checkStatement(Element element,String statementname){\n  if (element == null || statementname == null) {\n    return false;\n  }\n  String tag=element.getLocalName();\n  if (tag == null) {\n    return false;\n  }\n else   if (tag.equals(\"Statement\")) {\n    NamedNodeMap nm=element.getAttributes();\n    int len=nm.getLength();\n    String attrName=null;\n    Attr attr=null;\n    for (int j=0; j < len; j++) {\n      attr=(Attr)nm.item(j);\n      attrName=attr.getLocalName();\n      if ((attrName != null) && (attrName.equals(\"type\")) && (attr.getNodeValue().equals(statementname + \"Type\"))) {\n        return true;\n      }\n    }\n  }\n else   if (tag.equals(statementname)) {\n    return true;\n  }\n  return false;\n}\n
# I0620 11:56:17.968636 139711288199040 decoding.py:151] Inference results OUTPUT: Checks whether the given element is a variable.
# I0620 11:56:17.969861 139711288199040 decoding.py:136] Inference results INPUT: public static boolean isValidIPv4(String address){\n  if (address.length() == 0) {\n    return false;\n  }\n  int octet;\n  int octets=0;\n  String temp=address + \".\";\n  int pos;\n  int start=0;\n  while (start < temp.length() && (pos=temp.indexOf(\'.\',start)) > start) {\n    if (octets == 4) {\n      return false;\n    }\n    try {\n      octet=Integer.parseInt(temp.substring(start,pos));\n    }\n catch (    NumberFormatException ex) {\n      return false;\n    }\n    if (octet < 0 || octet > 255) {\n      return false;\n    }\n    start=pos + 1;\n    octets++;\n  }\n  return octets == 4;\n}\n
# I0620 11:56:17.970077 139711288199040 decoding.py:151] Inference results OUTPUT: Validate the given ipv4 address.
# I0620 11:56:17.971215 139711288199040 decoding.py:136] Inference results INPUT: final int internalNextInt(int origin,int bound){\n  int r=mix32(nextSeed());\n  if (origin < bound) {\n    int n=bound - origin, m=n - 1;\n    if ((n & m) == 0)     r=(r & m) + origin;\n else     if (n > 0) {\n      for (int u=r >>> 1; u + m - (r=u % n) < 0; u=mix32(nextSeed()) >>> 1)       ;\n      r+=origin;\n    }\n else {\n      while (r < origin || r >= bound)       r=mix32(nextSeed());\n    }\n  }\n  return r;\n}\n
# I0620 11:56:17.971447 139711288199040 decoding.py:151] Inference results OUTPUT: The form of nextint used by longstream spliterators.
# I0620 11:56:17.973108 139711288199040 decoding.py:136] Inference results INPUT: private void cancelAcquire(Node node){\n  if (node == null)   return;\n  node.thread=null;\n  Node pred=node.prev;\n  while (pred.waitStatus > 0)   node.prev=pred=pred.prev;\n  Node predNext=pred.next;\n  node.waitStatus=Node.CANCELLED;\n  if (node == tail && compareAndSetTail(node,pred)) {\n    compareAndSetNext(pred,predNext,null);\n  }\n else {\n    int ws;\n    if (pred != head && ((ws=pred.waitStatus) == Node.SIGNAL || (ws <= 0 && compareAndSetWaitStatus(pred,ws,Node.SIGNAL))) && pred.thread != null) {\n      Node next=node.next;\n      if (next != null && next.waitStatus <= 0)       compareAndSetNext(pred,predNext,next);\n    }\n else {\n      unparkSuccessor(node);\n    }\n    node.next=node;\n  }\n}\n
# I0620 11:56:17.973326 139711288199040 decoding.py:151] Inference results OUTPUT: Acquires in shared uninterruptible mode.
# I0620 11:56:17.974999 139711288199040 decoding.py:136] Inference results INPUT: Object processNUMBER(StylesheetHandler handler,String uri,String name,String rawName,String value,ElemTemplateElement owner) throws org.xml.sax.SAXException {\n  if (getSupportsAVT()) {\n    Double val;\n    AVT avt=null;\n    try {\n      avt=new AVT(handler,uri,name,rawName,value,owner);\n      if (avt.isSimple()) {\n        val=Double.valueOf(value);\n      }\n    }\n catch (    TransformerException te) {\n      throw new org.xml.sax.SAXException(te);\n    }\ncatch (    NumberFormatException nfe) {\n      handleError(handler,XSLTErrorResources.INVALID_NUMBER,new Object[]{name,value},nfe);\n      return null;\n    }\n    return avt;\n  }\n else {\n    try {\n      return Double.valueOf(value);\n    }\n catch (    NumberFormatException nfe) {\n      handleError(handler,XSLTErrorResources.INVALID_NUMBER,new Object[]{name,value},nfe);\n      return null;\n    }\n  }\n}\n
# I0620 11:56:17.975249 139711288199040 decoding.py:151] Inference results OUTPUT: Process an attribute string of type t_int into a string value.
# ...
# I0620 11:58:21.599255 139711288199040 decoding.py:136] Inference results INPUT: public Random(){\n  setSeed(System.currentTimeMillis() + System.identityHashCode(this));\n}\n
# I0620 11:58:21.599433 139711288199040 decoding.py:151] Inference results OUTPUT: Creates a new instance.
# I0620 11:58:21.599806 139711288199040 decoding.py:136] Inference results INPUT: public void initializePersistence(Handler<AsyncResult<Void>> resultHandler){\n  delegate.initializePersistence(resultHandler);\n}\n
# I0620 11:58:21.599997 139711288199040 decoding.py:151] Inference results OUTPUT: Initialize the async service.
# I0620 11:58:21.600363 139711288199040 decoding.py:136] Inference results INPUT: public SAXException(String message){\n  super(message);\n  this.exception=null;\n}\n
# I0620 11:58:21.600595 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new exception with the specified detail message. the cause is not initialized.
# I0620 11:58:21.600863 139711288199040 decoding.py:136] Inference results INPUT: public boolean isEmpty(){\n  return true;\n}\n
# I0620 11:58:21.601121 139711288199040 decoding.py:151] Inference results OUTPUT: Returns <tt>true</tt> if this map contains no key-value mappings.
# I0620 11:58:21.601461 139711288199040 decoding.py:136] Inference results INPUT: public PrivilegedActionException(Exception exception){\n  super((Throwable)null);\n  this.exception=exception;\n}\n
# I0620 11:58:21.601756 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new exception with the specified detail message, cause, and bean for jax-ws exception serialization.
# I0620 11:58:21.602125 139711288199040 decoding.py:136] Inference results INPUT: public boolean isReferral(){\n  return hasObjectClassOrAttribute(OC_REFERRAL,ATTR_REFERRAL_URL);\n}\n
# I0620 11:58:21.602289 139711288199040 decoding.py:151] Inference results OUTPUT: Returns whether it has the url.
# I0620 11:58:21.602503 139711288199040 decoding.py:136] Inference results INPUT: public int hashCode(){\n  return getName().hashCode();\n}\n
# I0620 11:58:21.602660 139711288199040 decoding.py:151] Inference results OUTPUT: Returns a hash code for this instance.
# I0620 11:58:21.603104 139711288199040 decoding.py:136] Inference results INPUT: public IndirectionException(int offset){\n  super(\"\",0,org.omg.CORBA.CompletionStatus.COMPLETED_MAYBE);\n  this.offset=offset;\n}\n
# I0620 11:58:21.603355 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new exception with the specified detail message. the cause is not initialized.
# I0620 11:58:21.603641 139711288199040 decoding.py:136] Inference results INPUT: public PdfSignatureBuildProperties(PdfDictionary dict){\n  super(dict);\n}\n
# I0620 11:58:21.603797 139711288199040 decoding.py:151] Inference results OUTPUT: Creates a new instance.
# I0620 11:58:21.604132 139711288199040 decoding.py:136] Inference results INPUT: public FSSAMLServiceViewBean(){\n  super(\"FSSAMLService\");\n  setDefaultDisplayURL(DEFAULT_DISPLAY_URL);\n}\n
# I0620 11:58:21.604367 139711288199040 decoding.py:151] Inference results OUTPUT: Creates a new instance of the switch. <!-- begin-user-doc --> <!-- end-user-doc -->.
# I0620 11:58:21.604603 139711288199040 decoding.py:136] Inference results INPUT: public HttpServletRequestWrapper(HttpServletRequest request){\n  super(request);\n}\n
# I0620 11:58:21.604938 139711288199040 decoding.py:151] Inference results OUTPUT: Creates a new request.
# I0620 11:58:21.605282 139711288199040 decoding.py:136] Inference results INPUT: public FrameBodyDeprecated(AbstractID3v2FrameBody frameBody){\n  this.originalFrameBody=frameBody;\n}\n
# I0620 11:58:21.605427 139711288199040 decoding.py:151] Inference results OUTPUT: Creates a new frame.
# I0620 11:58:21.605643 139711288199040 decoding.py:136] Inference results INPUT: public void testApp(){\n  assertTrue(true);\n}\n
# I0620 11:58:21.605844 139711288199040 decoding.py:151] Inference results OUTPUT: Test of getinstance method, of class abstractthrottle.
# I0620 11:58:21.606098 139711288199040 decoding.py:136] Inference results INPUT: public ImageWriteParam(Locale locale){\n  this.locale=locale;\n}\n
# I0620 11:58:21.606246 139711288199040 decoding.py:151] Inference results OUTPUT: Creates a new image store.
# I0620 11:58:21.606525 139711288199040 decoding.py:136] Inference results INPUT: public UserAttributeNotificationMessageTemplateElement(AttributeType attributeType){\n  this.attributeType=attributeType;\n}\n
# I0620 11:58:21.606746 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new exception with the specified detail message. the cause is not initialized.
# I0620 11:58:21.606992 139711288199040 decoding.py:136] Inference results INPUT: public DERSequence(ASN1Encodable[] array){\n  super(array);\n}\n
# I0620 11:58:21.607166 139711288199040 decoding.py:151] Inference results OUTPUT: Create a sequence containing an array of objects.
# I0620 11:58:21.607418 139711288199040 decoding.py:136] Inference results INPUT: public GeneralSecurityException(String msg){\n  super(msg);\n}\n
# I0620 11:58:21.607624 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new exception with the specified detail message. the cause is not initialized.
# I0620 11:58:21.607928 139711288199040 decoding.py:136] Inference results INPUT: private void quitClicked(){\n  application.quitClicked(getCurrentStep(),this);\n}\n
# I0620 11:58:21.608128 139711288199040 decoding.py:151] Inference results OUTPUT: This method is called when the user presses the back button.
# I0620 11:58:21.608361 139711288199040 decoding.py:136] Inference results INPUT: public InvalidConfigurationException(String msg){\n  super(msg);\n}\n
# I0620 11:58:21.608570 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new exception with the specified detail message. the cause is not initialized.
# I0620 11:58:21.608849 139711288199040 decoding.py:136] Inference results INPUT: public DefaultFormatter(){\n  overwriteMode=true;\n  allowsInvalid=true;\n}\n
# I0620 11:58:21.608989 139711288199040 decoding.py:151] Inference results OUTPUT: Creates a new instance.
# I0620 11:58:21.609231 139711288199040 decoding.py:136] Inference results INPUT: public AttributeMissingException(Throwable cause){\n  super(cause);\n}\n
# I0620 11:58:21.609469 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new exception with the specified detail message, cause, and bean for jax-ws exception serialization.
# I0620 11:58:21.609723 139711288199040 decoding.py:136] Inference results INPUT: public HyphenationException(String msg){\n  super(msg);\n}\n
# I0620 11:58:21.609930 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new exception with the specified detail message. the cause is not initialized.
# I0620 11:58:21.610184 139711288199040 decoding.py:136] Inference results INPUT: public BasicAttributes(boolean ignoreCase){\n  this.ignoreCase=ignoreCase;\n}\n
# I0620 11:58:21.610328 139711288199040 decoding.py:151] Inference results OUTPUT: Creates a new attribute.
# I0620 11:58:21.610507 139711288199040 decoding.py:136] Inference results INPUT: @Override public void flush(){\n}\n
# I0620 11:58:21.610666 139711288199040 decoding.py:151] Inference results OUTPUT: Flushes the output stream.
# I0620 11:58:21.610940 139711288199040 decoding.py:136] Inference results INPUT: protected void tearDown(){\n  Locale.setDefault(defaultLocale);\n}\n
# I0620 11:58:21.611217 139711288199040 decoding.py:151] Inference results OUTPUT: Tears down the fixture, for example, close a network connection. this method is called after a test is executed.
# I0620 11:58:21.611435 139711288199040 decoding.py:136] Inference results INPUT: public void doubleBufferingChanged(JRootPane rootPane){\n}\n
# I0620 11:58:21.611609 139711288199040 decoding.py:151] Inference results OUTPUT: This method is called when a new frame is created.
# I0620 11:58:21.611967 139711288199040 decoding.py:136] Inference results INPUT: public FSAuthDomainsEditViewBean(){\n  super(\"FSAuthDomainsEdit\");\n  setDefaultDisplayURL(DEFAULT_DISPLAY_URL);\n}\n
# I0620 11:58:21.612222 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new exception with <code>null</code> as its detail message. the cause is not initialized.
# I0620 11:58:21.612521 139711288199040 decoding.py:136] Inference results INPUT: void markInProgress(LDAPUpdateMsg msg){\n  remotePendingChanges.markInProgress(msg);\n}\n
# I0620 11:58:21.612701 139711288199040 decoding.py:151] Inference results OUTPUT: Marks the current position in the list.
# I0620 11:58:21.612930 139711288199040 decoding.py:136] Inference results INPUT: public SQLDataException(Throwable cause){\n  super(cause);\n}\n
# I0620 11:58:21.613229 139711288199040 decoding.py:151] Inference results OUTPUT: Creates an sqldataexception object. the reason string is set to the given reason string, the sqlstate string is set to the given cause throwable object.
# I0620 11:58:21.613744 139711288199040 decoding.py:136] Inference results INPUT: ArchiveException(String message,Exception cause){\n  super(message,cause);\n}\n
# I0620 11:58:21.613993 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new exception with the specified detail message. the cause is not initialized.
# I0620 11:58:21.614236 139711288199040 decoding.py:136] Inference results INPUT: public void internalFrameOpened(InternalFrameEvent e){\n}\n
# I0620 11:58:21.614397 139711288199040 decoding.py:151] Inference results OUTPUT: Called when a new frame is removed.
# I0620 11:58:21.615839 139709686658816 decoding.py:585] Decoding batch 15
# I0620 11:58:23.223989 139711288199040 decoding.py:136] Inference results INPUT: public CertificateNotYetValidException(){\n  super();\n}\n
# I0620 11:58:23.224512 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a certificateexception with no detail message. a detail message is a string that describes this particular exception.
# I0620 11:58:23.224776 139711288199040 decoding.py:136] Inference results INPUT: public OpenDataException(){\n  super();\n}\n
# I0620 11:58:23.225050 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new exception with <code>null</code> as its detail message. the cause is not initialized.
# I0620 11:58:23.225323 139711288199040 decoding.py:136] Inference results INPUT: public Hashtable(){\n  this(11,0.75f);\n}\n
# I0620 11:58:23.225545 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new, empty hashtable.
# I0620 11:58:23.225780 139711288199040 decoding.py:136] Inference results INPUT: public LogException(){\n  super();\n}\n
# I0620 11:58:23.226047 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new exception with <code>null</code> as its detail message. the cause is not initialized.
# I0620 11:58:23.226296 139711288199040 decoding.py:136] Inference results INPUT: public Segment(){\n  this(null,0,0);\n}\n
# I0620 11:58:23.226438 139711288199040 decoding.py:151] Inference results OUTPUT: Creates a new segment.
# I0620 11:58:23.226619 139711288199040 decoding.py:136] Inference results INPUT: public void enableLogging(){\n}\n
# I0620 11:58:23.226793 139711288199040 decoding.py:151] Inference results OUTPUT: Enables logging for this logger.
# I0620 11:58:23.227050 139711288199040 decoding.py:136] Inference results INPUT: public InvalidCredentialsException(){\n  super();\n}\n
# I0620 11:58:23.227310 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new exception with <code>null</code> as its detail message. the cause is not initialized.
# I0620 11:58:23.227520 139711288199040 decoding.py:136] Inference results INPUT: public InvalidKeyException(){\n  super();\n}\n
# I0620 11:58:23.227801 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new exception with <code>null</code> as its detail message. the cause is not initialized.
# I0620 11:58:23.228008 139711288199040 decoding.py:136] Inference results INPUT: protected void tearDown(){\n}\n
# I0620 11:58:23.228295 139711288199040 decoding.py:151] Inference results OUTPUT: Tears down the fixture, for example, close a network connection. this method is called after a test is executed.
# I0620 11:58:23.228512 139711288199040 decoding.py:136] Inference results INPUT: public InvalidAttributeValueException(){\n  super();\n}\n
# I0620 11:58:23.228784 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new exception with <code>null</code> as its detail message. the cause is not initialized.
# I0620 11:58:23.228988 139711288199040 decoding.py:136] Inference results INPUT: protected void tearDown(){\n}\n
# I0620 11:58:23.229302 139711288199040 decoding.py:151] Inference results OUTPUT: Tears down the fixture, for example, close a network connection. this method is called after a test is executed.
# I0620 11:58:23.229585 139711288199040 decoding.py:136] Inference results INPUT: void attachView(){\n  getPresenter().attachView(delegateCallback.getMvpView());\n}\n
# I0620 11:58:23.229803 139711288199040 decoding.py:151] Inference results OUTPUT: Attaches the view to the view.
# I0620 11:58:23.230037 139711288199040 decoding.py:136] Inference results INPUT: void reset(){\n  offset=intLen=0;\n}\n
# I0620 11:58:23.230212 139711288199040 decoding.py:151] Inference results OUTPUT: Reset the chaining variables.
# I0620 11:58:23.230484 139711288199040 decoding.py:136] Inference results INPUT: public ContextRuleSet(){\n  this(\"\");\n}\n
# I0620 11:58:23.230642 139711288199040 decoding.py:151] Inference results OUTPUT: Creates a new instance.
# I0620 11:58:23.230912 139711288199040 decoding.py:136] Inference results INPUT: public TableRowSorter(){\n  this(null);\n}\n
# I0620 11:58:23.231137 139711288199040 decoding.py:151] Inference results OUTPUT: Constructs a new <code>sortedsetsorter</code> instance.
# I0620 11:58:23.231357 139711288199040 decoding.py:136] Inference results INPUT: public DefaultHandler2(){\n}\n
# I0620 11:58:23.231529 139711288199040 decoding.py:151] Inference results OUTPUT: Creates a new instance.
# I0620 11:58:23.231751 139711288199040 decoding.py:136] Inference results INPUT: public SAML2ResponseData(){\n}\n
# I0620 11:58:23.231914 139711288199040 decoding.py:151] Inference results OUTPUT: Creates a new instance.
# I0620 11:58:23.232125 139711288199040 decoding.py:136] Inference results INPUT: public SQLRecoverableException(){\n}\n
# I0620 11:58:23.232511 139711288199040 decoding.py:151] Inference results OUTPUT: Creates an sqltransientexception object. the reason string is set to null, the sqlstate string is set to null and the error code is set to 0.
# I0620 11:58:23.232686 139711288199040 decoding.py:136] Inference results INPUT: public Locator2Impl(){\n}\n
# I0620 11:58:23.232837 139711288199040 decoding.py:151] Inference results OUTPUT: Creates a new instance.
# I0620 11:58:23.233036 139711288199040 decoding.py:136] Inference results INPUT: public FrameBodyTCOP(){\n}\n
# I0620 11:58:23.233182 139711288199040 decoding.py:151] Inference results OUTPUT: Creates a new instance.
# I0620 11:58:23.349457 139711288199040 decoding.py:436] Elapsed Time: 166.81083
# I0620 11:58:23.349747 139711288199040 decoding.py:440] Averaged Single Token Generation Time: 0.0019835 (time 166.0321143 count 83708)
# I0620 11:58:23.349847 139711288199040 decoding.py:454] Writing decodes into ./sampled_model.en
# W0620 11:58:23.351371 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/decoding.py:462: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# I0620 11:58:23.352679 139711288199040 decoding.py:860] Running decode hooks.
# W0620 11:58:23.353005 139711288199040 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/decoding.py:866: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# I0620 11:58:23.354120 139711288199040 decoding.py:876] Decode hooks done.
