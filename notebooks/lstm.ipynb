# %% [markdown]
# Run this cell until you get a tesla T4, if not go to runtime -> reset all runtimes and try utill you get one.

# %%
# !nvidia-smi
# Out:
# Mon Jun 17 09:39:51 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8    16W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Run this cell first to prepare your google drive

# %%
import os

# Load the Drive helper and mount
from google.colab import drive
# This will prompt for authorization.
drive.mount('/content/drive', force_remount=True)

# Create a folder to save the output
#if not os.path.isdir("/content/drive/My Drive/CodeTransformer"):
#  os.mkdir("/content/drive/My Drive/CodeTransformer")
#else:
#  print("Directory already exists, skipping...")
  
# Change working directory to this created folder
#os.chdir("/content/drive/My Drive/CodeTransformer")

# If the git does not exist, clone it, else open the folder
if not os.path.isdir("./Deep-Learning"):
  print("Initial clone of git repo...")
  # !git clone https://github.com/jverbraeken/Deep-Learning.git
  os.chdir("./Deep-Learning")
else:
  print("Folder exists, pulling git repo...")
  os.chdir("./Deep-Learning")
  # !git pull

# Create folders for Tensor2Tensor to operate in
if not os.path.isdir("./data"):
  print("Creating data folder...")
  os.mkdir("./data")

if not os.path.isdir("./tmp"):
  print("Creating tmp folder...")
  os.mkdir("./tmp")

if not os.path.isdir("./output"):
  print("Creating output folder...")
  os.mkdir("./output")
  
# Should print a list of folders and files from the git
# !ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Initial clone of git repo...
# Cloning into 'Deep-Learning'...
# remote: Enumerating objects: 234, done.
# remote: Total 234 (delta 0), reused 0 (delta 0), pack-reused 234
# Receiving objects: 100% (234/234), 344.90 MiB | 48.21 MiB/s, done.
# Resolving deltas: 100% (102/102), done.
# Creating data folder...
# Creating tmp folder...
# Creating output folder...
# data		    output			 transformer
# data.7z		    prepare_transformer_data.py  transformer_data
# Evaluation	    preprocess			 transformer_preproc
# evaluation_scripts  readme.md
# models		    tmp

# %% [markdown]
# # (Optional) Load model from drive

# %%
# !unzip /content/drive/My\ Drive/model13.zip
# Out:
# Archive:  /content/drive/My Drive/model13.zip
#   inflating: output/events.out.tfevents.1560198226.4f4bcf4999eb
#   inflating: output/model.ckpt-316000.index
#   inflating: output/events.out.tfevents.1559823069.306770c51666
#   inflating: output/events.out.tfevents.1559564653.d3795f2f3185
#   inflating: output/model.ckpt-316000.data-00001-of-00002
#   inflating: output/model.ckpt-316000.meta
#    creating: output/eval/
#   inflating: output/eval/events.out.tfevents.1559633038.9caa77013cec
#   inflating: output/eval/events.out.tfevents.1559650193.9caa77013cec
#   inflating: output/eval/events.out.tfevents.1559565274.d3795f2f3185
#   inflating: output/eval/events.out.tfevents.1559721298.c2f81932b7cb
#   inflating: output/eval/events.out.tfevents.1559895989.8f5e0af1a077
#   inflating: output/eval/events.out.tfevents.1560198791.4f4bcf4999eb
#   inflating: output/eval/events.out.tfevents.1560153938.4eb99f03d590
#   inflating: output/eval/events.out.tfevents.1560071741.f9bb4b183132
#   inflating: output/eval/events.out.tfevents.1560237244.fee8b0a59ca1
#   inflating: output/eval/events.out.tfevents.1559939925.df0da9fd69ae
#   inflating: output/eval/events.out.tfevents.1559823630.306770c51666
#   inflating: output/graph.pbtxt
#   inflating: output/hparams.json
#   inflating: output/checkpoint
#   inflating: output/events.out.tfevents.1559649585.9caa77013cec
#   inflating: output/events.out.tfevents.1559632450.9caa77013cec
#   inflating: output/events.out.tfevents.1560153367.4eb99f03d590
#   inflating: output/events.out.tfevents.1559895377.8f5e0af1a077
#   inflating: output/flags.txt
#   inflating: output/flags_t2t.txt
#   inflating: output/events.out.tfevents.1560236352.fee8b0a59ca1
#   inflating: output/events.out.tfevents.1560071191.f9bb4b183132
#   inflating: output/events.out.tfevents.1559720772.c2f81932b7cb
#   inflating: output/model.ckpt-316000.data-00000-of-00002
#   inflating: output/events.out.tfevents.1559939385.df0da9fd69ae

# %% [markdown]
# # Run tensorboard

# %%
LOG_DIR = './output'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)
# Install
! npm install -g localtunnel

# Tunnel port 6006 (TensorBoard assumed running)
get_ipython().system_raw('lt --port 6006 >> url.txt 2>&1 &')
# Out:
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/client
# + localtunnel@1.9.1
# added 55 packages from 34 contributors in 3.531s

# %%
# !cat url.txt
# Out:
# your url is: https://afraid-firefox-3.localtunnel.me

# %% [markdown]
# # Run this cell to generate the data for the Transformer

# %%
# !t2t-datagen --t2t_usr_dir=./transformer_preproc --data_dir=./data --tmp_dir=./tmp --problem=code_transformer_preproc
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0617 09:48:16.223798 140085562398592 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/expert_utils.py:68: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0617 09:48:17.128070 140085562398592 deprecation_wrapper.py:119] From /usr/local/bin/t2t-datagen:27: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0617 09:48:17.128292 140085562398592 deprecation_wrapper.py:119] From /usr/local/bin/t2t-datagen:27: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W0617 09:48:17.128438 140085562398592 deprecation_wrapper.py:119] From /usr/local/bin/t2t-datagen:28: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0617 09:48:17.128964 140085562398592 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/usr_dir.py:42: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# I0617 09:48:17.129100 140085562398592 usr_dir.py:43] Importing user module transformer_preproc from path /content/Deep-Learning
# W0617 09:48:17.132550 140085562398592 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/bin/t2t_datagen.py:185: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# I0617 09:48:17.132740 140085562398592 t2t_datagen.py:189] Generating problems:
#     code:
#       * code_transformer_preproc
# W0617 09:48:17.132879 140085562398592 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/bin/t2t_datagen.py:140: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# I0617 09:48:17.137453 140085562398592 t2t_datagen.py:239] Generating data for code_transformer_preproc.
# :::MLPv0.5.0 transformer 1560764897.535254002 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/text_problems.py:306) preproc_tokenize_training
# I0617 09:48:17.535290 140085562398592 mlperf_log.py:156] :::MLPv0.5.0 transformer 1560764897.535254002 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/text_problems.py:306) preproc_tokenize_training
# W0617 09:48:17.535581 140085562398592 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/translate.py:133: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# W0617 09:48:17.535803 140085562398592 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/translate.py:137: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# I0617 09:48:17.535995 140085562398592 generator_utils.py:231] Downloading https://github.com/jverbraeken/Deep-Learning/blob/master/transformer_data/train_preproc.tgz?raw=true to ./tmp/train_preproc.tgz?raw=true
# W0617 09:48:17.536108 140085562398592 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/generator_utils.py:233: The name tf.gfile.Copy is deprecated. Please use tf.io.gfile.copy instead.
#
# 100% completed
# W0617 09:48:19.162728 140085562398592 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/generator_utils.py:241: The name tf.gfile.Rename is deprecated. Please use tf.io.gfile.rename instead.
#
# I0617 09:48:19.163022 140085562398592 generator_utils.py:246] Successfully downloaded train_preproc.tgz?raw=true, 75312383 bytes.
# I0617 09:48:29.570754 140085562398592 generator_utils.py:348] Generating vocab file: ./data/vocab.code_transformer_preproc.8192.subwords
# I0617 09:48:29.571027 140085562398592 generator_utils.py:371] Generating vocab from: [['https://github.com/jverbraeken/Deep-Learning/blob/master/transformer_data/train_preproc.tgz?raw=true', ('train/train.cd', 'train/train.en')]]
# I0617 09:48:29.571182 140085562398592 generator_utils.py:228] Not downloading, file already found: ./tmp/train_preproc.tgz?raw=true
# I0617 09:48:29.571255 140085562398592 generator_utils.py:378] Reading file: train/train.cd
# I0617 09:48:31.236524 140085562398592 generator_utils.py:378] Reading file: train/train.en
# I0617 09:48:32.385519 140085562398592 text_encoder.py:724] Trying min_count 500
# I0617 09:48:32.418425 140085562398592 text_encoder.py:804] Iteration 0
# I0617 09:48:33.715112 140085562398592 text_encoder.py:827] Processing token [zaosys5gm15khqzgs5ic9bjohhaoeru54zs7r2innc4cyutexqjxvjeivtvymsv8jvet3kenr0xtuvsqghmyuwslosafguwhjlr2urlozf1egjfwz2smo9rj3ajtrw3lvn8nngpd2evb9j6efbodxldoti03axilnqn0iiqomb8yomkm7ityvpemxj5myttcjropzaqi] took 0.115607976913 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:48:35.221558 140085562398592 text_encoder.py:827] Processing token [ - <\" + ] took 0.210149049759 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:48:37.501091 140085562398592 text_encoder.py:868] vocab_size = 1172
# I0617 09:48:37.501311 140085562398592 text_encoder.py:804] Iteration 1
# I0617 09:48:41.207645 140085562398592 text_encoder.py:827] Processing token [FEATURES] took 0.177597999573 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:48:42.301676 140085562398592 text_encoder.py:868] vocab_size = 620
# I0617 09:48:42.301927 140085562398592 text_encoder.py:804] Iteration 2
# I0617 09:48:45.759767 140085562398592 text_encoder.py:827] Processing token [s9jsiishis2lco1igdt5jikqykdsckzy] took 0.155355930328 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:48:47.030431 140085562398592 text_encoder.py:868] vocab_size = 663
# I0617 09:48:47.030652 140085562398592 text_encoder.py:804] Iteration 3
# I0617 09:48:50.487565 140085562398592 text_encoder.py:827] Processing token [np3ojhudirnwl7pjxsrvu3wertimy44sj0t] took 0.146600008011 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:48:51.760680 140085562398592 text_encoder.py:868] vocab_size = 652
# I0617 09:48:52.492921 140085562398592 text_encoder.py:724] Trying min_count 250
# I0617 09:48:52.523370 140085562398592 text_encoder.py:804] Iteration 0
# I0617 09:48:55.191740 140085562398592 text_encoder.py:827] Processing token [ - <\" + ] took 0.147835969925 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:48:57.510170 140085562398592 text_encoder.py:868] vocab_size = 2078
# I0617 09:48:57.510391 140085562398592 text_encoder.py:804] Iteration 1
# I0617 09:49:01.158304 140085562398592 text_encoder.py:827] Processing token [ihpyte9wouyqhxgrl4juckmxcdzpuqvpjbhk8kpesg7tcgjoso2bjapddsjohr0ltqgofccqbubk4ffgq61pqbjtxqhzbfbwi8vzz2auydcw] took 0.151375055313 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:49:02.033138 140085562398592 text_encoder.py:868] vocab_size = 1021
# I0617 09:49:02.033355 140085562398592 text_encoder.py:804] Iteration 2
# I0617 09:49:05.550642 140085562398592 text_encoder.py:827] Processing token [c1jepjmkmkecenrlrrlgck2kzjv4rrkl2wfntppg0pk2ebsnuexwmodjzy8vl4d0ny1l9hs3rgljrzqgpkvsz0] took 0.148025989532 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:49:06.658341 140085562398592 text_encoder.py:868] vocab_size = 1092
# I0617 09:49:06.658574 140085562398592 text_encoder.py:804] Iteration 3
# I0617 09:49:10.122392 140085562398592 text_encoder.py:827] Processing token [] took 0.177212953568 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:49:11.169382 140085562398592 text_encoder.py:868] vocab_size = 1082
# I0617 09:49:11.852752 140085562398592 text_encoder.py:724] Trying min_count 125
# I0617 09:49:11.881541 140085562398592 text_encoder.py:804] Iteration 0
# I0617 09:49:14.534220 140085562398592 text_encoder.py:827] Processing token [ - <\" + ] took 0.14876294136 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:49:17.288388 140085562398592 text_encoder.py:868] vocab_size = 3723
# I0617 09:49:17.288602 140085562398592 text_encoder.py:804] Iteration 1
# I0617 09:49:21.479142 140085562398592 text_encoder.py:868] vocab_size = 1661
# I0617 09:49:21.479363 140085562398592 text_encoder.py:804] Iteration 2
# I0617 09:49:24.730900 140085562398592 text_encoder.py:827] Processing token [ijazcar5liuk1nhhbjvvik1w2cfbasiilnk4psjdcpzlsvkunezkwnsxh8mihvcfoqgdi1viaodxcuxtgrbpviqh] took 0.149313926697 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:49:25.628071 140085562398592 text_encoder.py:868] vocab_size = 1784
# I0617 09:49:25.628324 140085562398592 text_encoder.py:804] Iteration 3
# I0617 09:49:28.993737 140085562398592 text_encoder.py:827] Processing token [w0iu2tyr2e9551btisgeiyobbeboyzytriomtiijgua7ivn8sgp6vryr8s] took 0.14955997467 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:49:29.854038 140085562398592 text_encoder.py:868] vocab_size = 1758
# I0617 09:49:30.501398 140085562398592 text_encoder.py:724] Trying min_count 62
# I0617 09:49:30.531402 140085562398592 text_encoder.py:804] Iteration 0
# I0617 09:49:33.133433 140085562398592 text_encoder.py:827] Processing token [ - <\" + ] took 0.148530006409 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:49:35.908652 140085562398592 text_encoder.py:868] vocab_size = 6708
# I0617 09:49:35.908863 140085562398592 text_encoder.py:804] Iteration 1
# I0617 09:49:39.824399 140085562398592 text_encoder.py:868] vocab_size = 2730
# I0617 09:49:39.824614 140085562398592 text_encoder.py:804] Iteration 2
# I0617 09:49:43.714956 140085562398592 text_encoder.py:868] vocab_size = 3065
# I0617 09:49:43.715171 140085562398592 text_encoder.py:804] Iteration 3
# I0617 09:49:47.469341 140085562398592 text_encoder.py:868] vocab_size = 2924
# I0617 09:49:47.977917 140085562398592 text_encoder.py:724] Trying min_count 31
# I0617 09:49:48.012850 140085562398592 text_encoder.py:804] Iteration 0
# I0617 09:49:50.612025 140085562398592 text_encoder.py:827] Processing token [ - <\" + ] took 0.150165081024 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:49:53.781696 140085562398592 text_encoder.py:868] vocab_size = 11493
# I0617 09:49:53.781928 140085562398592 text_encoder.py:804] Iteration 1
# I0617 09:49:57.523024 140085562398592 text_encoder.py:868] vocab_size = 4570
# I0617 09:49:57.523277 140085562398592 text_encoder.py:804] Iteration 2
# I0617 09:50:00.844295 140085562398592 text_encoder.py:868] vocab_size = 5026
# I0617 09:50:00.844549 140085562398592 text_encoder.py:804] Iteration 3
# I0617 09:50:04.099827 140085562398592 text_encoder.py:868] vocab_size = 4930
# I0617 09:50:04.526596 140085562398592 text_encoder.py:724] Trying min_count 15
# I0617 09:50:04.556282 140085562398592 text_encoder.py:804] Iteration 0
# I0617 09:50:07.141211 140085562398592 text_encoder.py:827] Processing token [ - <\" + ] took 0.152560949326 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:50:10.386332 140085562398592 text_encoder.py:868] vocab_size = 19397
# I0617 09:50:10.386548 140085562398592 text_encoder.py:804] Iteration 1
# I0617 09:50:14.154501 140085562398592 text_encoder.py:868] vocab_size = 7497
# I0617 09:50:14.154803 140085562398592 text_encoder.py:804] Iteration 2
# I0617 09:50:17.209465 140085562398592 text_encoder.py:868] vocab_size = 7864
# I0617 09:50:17.209784 140085562398592 text_encoder.py:804] Iteration 3
# I0617 09:50:20.249275 140085562398592 text_encoder.py:868] vocab_size = 7810
# I0617 09:50:20.646584 140085562398592 text_encoder.py:724] Trying min_count 7
# I0617 09:50:20.676697 140085562398592 text_encoder.py:804] Iteration 0
# I0617 09:50:23.245033 140085562398592 text_encoder.py:827] Processing token [ - <\" + ] took 0.149979114532 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:50:26.600059 140085562398592 text_encoder.py:868] vocab_size = 35296
# I0617 09:50:26.600292 140085562398592 text_encoder.py:804] Iteration 1
# I0617 09:50:30.227868 140085562398592 text_encoder.py:868] vocab_size = 11927
# I0617 09:50:30.228111 140085562398592 text_encoder.py:804] Iteration 2
# I0617 09:50:33.347635 140085562398592 text_encoder.py:868] vocab_size = 12523
# I0617 09:50:33.347856 140085562398592 text_encoder.py:804] Iteration 3
# I0617 09:50:36.304821 140085562398592 text_encoder.py:868] vocab_size = 12412
# I0617 09:50:36.691174 140085562398592 text_encoder.py:724] Trying min_count 11
# I0617 09:50:36.720655 140085562398592 text_encoder.py:804] Iteration 0
# I0617 09:50:39.243822 140085562398592 text_encoder.py:827] Processing token [ - <\" + ] took 0.151683092117 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:50:42.504743 140085562398592 text_encoder.py:868] vocab_size = 24579
# I0617 09:50:42.504993 140085562398592 text_encoder.py:804] Iteration 1
# I0617 09:50:46.235362 140085562398592 text_encoder.py:868] vocab_size = 9099
# I0617 09:50:46.235591 140085562398592 text_encoder.py:804] Iteration 2
# I0617 09:50:49.388851 140085562398592 text_encoder.py:868] vocab_size = 9531
# I0617 09:50:49.389084 140085562398592 text_encoder.py:804] Iteration 3
# I0617 09:50:52.532177 140085562398592 text_encoder.py:868] vocab_size = 9409
# I0617 09:50:52.927558 140085562398592 text_encoder.py:724] Trying min_count 13
# I0617 09:50:52.957801 140085562398592 text_encoder.py:804] Iteration 0
# I0617 09:50:55.446229 140085562398592 text_encoder.py:827] Processing token [ - <\" + ] took 0.148941993713 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:50:58.641144 140085562398592 text_encoder.py:868] vocab_size = 21662
# I0617 09:50:58.641391 140085562398592 text_encoder.py:804] Iteration 1
# I0617 09:51:02.345036 140085562398592 text_encoder.py:868] vocab_size = 8193
# I0617 09:51:02.345284 140085562398592 text_encoder.py:804] Iteration 2
# I0617 09:51:05.509742 140085562398592 text_encoder.py:868] vocab_size = 8605
# I0617 09:51:05.509995 140085562398592 text_encoder.py:804] Iteration 3
# I0617 09:51:08.552727 140085562398592 text_encoder.py:868] vocab_size = 8492
# I0617 09:51:08.958386 140085562398592 text_encoder.py:724] Trying min_count 14
# I0617 09:51:08.988325 140085562398592 text_encoder.py:804] Iteration 0
# I0617 09:51:11.509202 140085562398592 text_encoder.py:827] Processing token [ - <\" + ] took 0.148453950882 seconds, consider setting Text2TextProblem.max_subtoken_length to a smaller value.
# I0617 09:51:14.750226 140085562398592 text_encoder.py:868] vocab_size = 20443
# I0617 09:51:14.750442 140085562398592 text_encoder.py:804] Iteration 1
# I0617 09:51:18.278028 140085562398592 text_encoder.py:868] vocab_size = 7829
# I0617 09:51:18.278244 140085562398592 text_encoder.py:804] Iteration 2
# I0617 09:51:21.476532 140085562398592 text_encoder.py:868] vocab_size = 8214
# I0617 09:51:21.476794 140085562398592 text_encoder.py:804] Iteration 3
# I0617 09:51:24.486066 140085562398592 text_encoder.py:868] vocab_size = 8105
# W0617 09:51:24.979798 140085562398592 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/generator_utils.py:163: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# I0617 09:51:29.554480 140085562398592 generator_utils.py:169] Generating case 0.

# %% [markdown]
# # Run this cell to train the Transformer

# %%
# !t2t-trainer --generate_data --t2t_usr_dir=./transformer_preproc --data_dir=./data --output_dir=./output --problem=code_transformer_preproc --model=lstm_seq2seq --hparams_set=lstm_seq2seq --hparams='batch_size=1024' --keep_checkpoint_max=1 --train_steps=720000
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# :::MLPv0.5.0 transformer 1560236322.689806938 (/usr/local/bin/t2t-trainer:28) run_set_random_seed
# INFO:tensorflow:Importing user module transformer_preproc from path /content/Deep-Learning
# INFO:tensorflow:Generating data for code_transformer_preproc
# :::MLPv0.5.0 transformer 1560236322.693063021 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/text_problems.py:306) preproc_tokenize_training
# INFO:tensorflow:Downloading https://github.com/jverbraeken/Deep-Learning/blob/master/transformer_data/train_preproc.tgz?raw=true to /tmp/t2t_datagen/train_preproc.tgz?raw=true
# 100% completed
# INFO:tensorflow:Successfully downloaded train_preproc.tgz?raw=true, 75312383 bytes.
# INFO:tensorflow:Found vocab file: ./data/vocab.code_transformer_preproc.8192.subwords
# INFO:tensorflow:Skipping generator because outputs files exists at ['./data/code_transformer_preproc-unshuffled-train-00000-of-00100', './data/code_transformer_preproc-unshuffled-train-00001-of-00100', './data/code_transformer_preproc-unshuffled-train-00002-of-00100', './data/code_transformer_preproc-unshuffled-train-00003-of-00100', './data/code_transformer_preproc-unshuffled-train-00004-of-00100', './data/code_transformer_preproc-unshuffled-train-00005-of-00100', './data/code_transformer_preproc-unshuffled-train-00006-of-00100', './data/code_transformer_preproc-unshuffled-train-00007-of-00100', './data/code_transformer_preproc-unshuffled-train-00008-of-00100', './data/code_transformer_preproc-unshuffled-train-00009-of-00100', './data/code_transformer_preproc-unshuffled-train-00010-of-00100', './data/code_transformer_preproc-unshuffled-train-00011-of-00100', './data/code_transformer_preproc-unshuffled-train-00012-of-00100', './data/code_transformer_preproc-unshuffled-train-00013-of-00100', './data/code_transformer_preproc-unshuffled-train-00014-of-00100', './data/code_transformer_preproc-unshuffled-train-00015-of-00100', './data/code_transformer_preproc-unshuffled-train-00016-of-00100', './data/code_transformer_preproc-unshuffled-train-00017-of-00100', './data/code_transformer_preproc-unshuffled-train-00018-of-00100', './data/code_transformer_preproc-unshuffled-train-00019-of-00100', './data/code_transformer_preproc-unshuffled-train-00020-of-00100', './data/code_transformer_preproc-unshuffled-train-00021-of-00100', './data/code_transformer_preproc-unshuffled-train-00022-of-00100', './data/code_transformer_preproc-unshuffled-train-00023-of-00100', './data/code_transformer_preproc-unshuffled-train-00024-of-00100', './data/code_transformer_preproc-unshuffled-train-00025-of-00100', './data/code_transformer_preproc-unshuffled-train-00026-of-00100', './data/code_transformer_preproc-unshuffled-train-00027-of-00100', './data/code_transformer_preproc-unshuffled-train-00028-of-00100', './data/code_transformer_preproc-unshuffled-train-00029-of-00100', './data/code_transformer_preproc-unshuffled-train-00030-of-00100', './data/code_transformer_preproc-unshuffled-train-00031-of-00100', './data/code_transformer_preproc-unshuffled-train-00032-of-00100', './data/code_transformer_preproc-unshuffled-train-00033-of-00100', './data/code_transformer_preproc-unshuffled-train-00034-of-00100', './data/code_transformer_preproc-unshuffled-train-00035-of-00100', './data/code_transformer_preproc-unshuffled-train-00036-of-00100', './data/code_transformer_preproc-unshuffled-train-00037-of-00100', './data/code_transformer_preproc-unshuffled-train-00038-of-00100', './data/code_transformer_preproc-unshuffled-train-00039-of-00100', './data/code_transformer_preproc-unshuffled-train-00040-of-00100', './data/code_transformer_preproc-unshuffled-train-00041-of-00100', './data/code_transformer_preproc-unshuffled-train-00042-of-00100', './data/code_transformer_preproc-unshuffled-train-00043-of-00100', './data/code_transformer_preproc-unshuffled-train-00044-of-00100', './data/code_transformer_preproc-unshuffled-train-00045-of-00100', './data/code_transformer_preproc-unshuffled-train-00046-of-00100', './data/code_transformer_preproc-unshuffled-train-00047-of-00100', './data/code_transformer_preproc-unshuffled-train-00048-of-00100', './data/code_transformer_preproc-unshuffled-train-00049-of-00100', './data/code_transformer_preproc-unshuffled-train-00050-of-00100', './data/code_transformer_preproc-unshuffled-train-00051-of-00100', './data/code_transformer_preproc-unshuffled-train-00052-of-00100', './data/code_transformer_preproc-unshuffled-train-00053-of-00100', './data/code_transformer_preproc-unshuffled-train-00054-of-00100', './data/code_transformer_preproc-unshuffled-train-00055-of-00100', './data/code_transformer_preproc-unshuffled-train-00056-of-00100', './data/code_transformer_preproc-unshuffled-train-00057-of-00100', './data/code_transformer_preproc-unshuffled-tr ...
# :::MLPv0.5.0 transformer 1560236343.830931902 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/text_problems.py:306) preproc_tokenize_eval
# INFO:tensorflow:Downloading https://github.com/jverbraeken/Deep-Learning/blob/master/transformer_data/test_preproc.tgz?raw=true to /tmp/t2t_datagen/test_preproc.tgz?raw=true
# 100% completed
# INFO:tensorflow:Successfully downloaded test_preproc.tgz?raw=true, 8501595 bytes.
# INFO:tensorflow:Found vocab file: ./data/vocab.code_transformer_preproc.8192.subwords
# INFO:tensorflow:Skipping generator because outputs files exists at ['./data/code_transformer_preproc-unshuffled-dev-00000-of-00001']
# INFO:tensorflow:Skipping shuffle because output files exist
# INFO:tensorflow:Loading hparams from existing json ./output/hparams.json
# INFO:tensorflow:Overriding hparams in lstm_seq2seq with batch_size=1024
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/trainer_lib.py:278: __init__ (from tensorflow.contrib.learn.python.learn.estimators.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.RunConfig instead.
# INFO:tensorflow:Configuring DataParallelism to replicate the model.
# INFO:tensorflow:schedule=continuous_train_and_eval
# INFO:tensorflow:worker_gpu=1
# INFO:tensorflow:sync=False
# WARNING:tensorflow:Schedule=continuous_train_and_eval. Assuming that training is running on a single machine.
# INFO:tensorflow:datashard_devices: ['gpu:0']
# INFO:tensorflow:caching_devices: None
# INFO:tensorflow:ps_devices: ['gpu:0']
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': None, '_num_ps_replicas': 0, '_keep_checkpoint_max': 1, '_task_type': None, '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fab5ec14590>, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_protocol': None, '_save_checkpoints_steps': 1000, '_keep_checkpoint_every_n_hours': 10000, '_session_config': gpu_options {
#   per_process_gpu_memory_fraction: 0.95
# }
# allow_soft_placement: true
# graph_options {
#   optimizer_options {
#     global_jit_level: OFF
#   }
# }
# , '_model_dir': './output', 'use_tpu': False, '_tf_random_seed': None, '_master': '', '_device_fn': None, '_num_worker_replicas': 0, '_task_id': 0, '_log_step_count_steps': 100, '_evaluation_master': '', '_eval_distribute': None, 'data_parallelism': <tensor2tensor.utils.expert_utils.Parallelism object at 0x7fab53217050>, '_environment': 'local', '_save_summary_steps': 100, 't2t_device_info': {'num_async_replicas': 1}}
# WARNING:tensorflow:Estimator's model_fn (<function wrapping_model_fn at 0x7fab531f12a8>) includes params argument, but params are not passed to Estimator.
# WARNING:tensorflow:ValidationMonitor only works with --schedule=train_and_evaluate
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1000 or save_checkpoints_secs None.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# :::MLPv0.5.0 transformer 1560236347.794399023 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/problem.py:759) input_max_length: 1024
# INFO:tensorflow:Reading data files from ./data/code_transformer_preproc-train*
# INFO:tensorflow:partition: 0 num_data_files: 100
# :::MLPv0.5.0 transformer 1560236347.797771931 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/problem.py:872) input_order
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/problem.py:654: parallel_interleave (from tensorflow.contrib.data.python.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.parallel_interleave(...)`.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/problem.py:172: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/data_reader.py:31: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/problem.py:947: bucket_by_sequence_length (from tensorflow.contrib.data.python.ops.grouping) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.bucket_by_sequence_length(...)`.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/problem.py:1211: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Setting T2TModel mode to 'train'
# :::MLPv0.5.0 transformer 1560236348.780689955 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/t2t_model.py:228) model_hp_initializer_gain: 1.0
# INFO:tensorflow:Using variable initializer: uniform_unit_scaling
# INFO:tensorflow:Transforming feature 'inputs' with symbol_modality_8105_128.bottom
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/function.py:1007: calling create_op (from tensorflow.python.framework.ops) with compute_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# Shapes are always computed; don't use the compute_shapes as it has no effect.
# INFO:tensorflow:Transforming feature 'targets' with symbol_modality_8105_128.targets_bottom
# INFO:tensorflow:Building model body
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/models/lstm.py:33: __init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/models/lstm.py:61: __init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/models/lstm.py:66: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/rnn_cell_impl.py:1259: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# INFO:tensorflow:Transforming body output with symbol_modality_8105_128.top
# :::MLPv0.5.0 transformer 1560236349.945635080 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/t2t_model.py:582) opt_learning_rate: "DEFERRED: f019291d-bb4e-4ffa-bae0-df8bd7f94374"
# :::MLPv0.5.0 transformer 1560236349.946644068 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/t2t_model.py:582) opt_learning_rate_warmup_steps: 100
# INFO:tensorflow:Applying exp learning rate warmup for 100 steps
# INFO:tensorflow:Base learning rate: 0.100000
# INFO:tensorflow:Trainable Variables Total size: 3638656
# INFO:tensorflow:Non-trainable variables Total size: 5
# INFO:tensorflow:Using optimizer Adam
# :::MLPv0.5.0 transformer 1560236349.971199036 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/optimize.py:53) opt_name: "Adam"
# :::MLPv0.5.0 transformer 1560236349.972147942 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/optimize.py:53) opt_hp_Adam_beta1: 0.85
# :::MLPv0.5.0 transformer 1560236349.973069906 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/optimize.py:53) opt_hp_Adam_beta2: 0.997
# :::MLPv0.5.0 transformer 1560236349.974000931 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/optimize.py:53) opt_hp_Adam_epsilon: 1e-06
# INFO:tensorflow:Clipping gradients, norm: 2.00000
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# 2019-06-11 06:59:12.977617: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-06-11 06:59:12.978088: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x561a97026520 executing computations on platform Host. Devices:
# 2019-06-11 06:59:12.978132: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-06-11 06:59:13.140164: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-11 06:59:13.140916: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x561a97027c80 executing computations on platform CUDA. Devices:
# 2019-06-11 06:59:13.140957: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-06-11 06:59:13.141401: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-06-11 06:59:13.141439: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-06-11 06:59:14.540337: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-11 06:59:14.540431: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-06-11 06:59:14.540464: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-06-11 06:59:14.540784: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-06-11 06:59:14.540894: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10869 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./output/model.ckpt-313000
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/training/saver.py:1070: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 313000 into ./output/model.ckpt.
# 2019-06-11 06:59:19.649285: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# INFO:tensorflow:loss = 2.518621, step = 313000
# INFO:tensorflow:global_step/sec: 1.11673
# INFO:tensorflow:loss = 3.1876404, step = 313100 (89.548 sec)
# INFO:tensorflow:global_step/sec: 1.16105
# INFO:tensorflow:loss = 3.2521207, step = 313200 (86.129 sec)
# INFO:tensorflow:global_step/sec: 1.09726
# INFO:tensorflow:loss = 3.6071563, step = 313300 (91.136 sec)
# INFO:tensorflow:global_step/sec: 1.13131
# INFO:tensorflow:loss = 3.0117207, step = 313400 (88.393 sec)
# INFO:tensorflow:global_step/sec: 1.17385
# INFO:tensorflow:loss = 4.3063183, step = 313500 (85.190 sec)
# INFO:tensorflow:global_step/sec: 1.19038
# INFO:tensorflow:loss = 3.4110587, step = 313600 (84.007 sec)
# INFO:tensorflow:global_step/sec: 1.14865
# INFO:tensorflow:loss = 2.6708238, step = 313700 (87.058 sec)
# INFO:tensorflow:global_step/sec: 0.998391
# INFO:tensorflow:loss = 4.3124866, step = 313800 (100.161 sec)
# INFO:tensorflow:global_step/sec: 1.20796
# INFO:tensorflow:loss = 3.6282046, step = 313900 (82.784 sec)
# INFO:tensorflow:Saving checkpoints for 314000 into ./output/model.ckpt.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/training/saver.py:966: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# :::MLPv0.5.0 transformer 1560237241.945209980 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/problem.py:759) input_max_length: 1024
# INFO:tensorflow:Reading data files from ./data/code_transformer_preproc-dev*
# INFO:tensorflow:partition: 0 num_data_files: 1
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Setting T2TModel mode to 'eval'
# INFO:tensorflow:Setting hparams.layer_prepostprocess_dropout to 0.0
# INFO:tensorflow:Setting hparams.symbol_dropout to 0.0
# INFO:tensorflow:Setting hparams.label_smoothing to 0.0
# INFO:tensorflow:Setting hparams.dropout to 0.0
# :::MLPv0.5.0 transformer 1560237242.826246977 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/t2t_model.py:228) model_hp_initializer_gain: 1.0
# INFO:tensorflow:Using variable initializer: uniform_unit_scaling
# INFO:tensorflow:Transforming feature 'inputs' with symbol_modality_8105_128.bottom
# INFO:tensorflow:Transforming feature 'targets' with symbol_modality_8105_128.targets_bottom
# INFO:tensorflow:Building model body
# INFO:tensorflow:Transforming body output with symbol_modality_8105_128.top
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/bleu_hook.py:151: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, use
#     tf.py_function, which takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-11T07:14:04Z
# INFO:tensorflow:Graph was finalized.
# 2019-06-11 07:14:05.340014: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-06-11 07:14:05.340109: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-11 07:14:05.340142: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-06-11 07:14:05.340161: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-06-11 07:14:05.340470: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10869 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# INFO:tensorflow:Restoring parameters from ./output/model.ckpt-314000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-11-07:14:59
# INFO:tensorflow:Saving dict for global step 314000: global_step = 314000, loss = 3.8741696, metrics-code_transformer_preproc/targets/accuracy = 0.35501876, metrics-code_transformer_preproc/targets/accuracy_per_sequence = 0.004255319, metrics-code_transformer_preproc/targets/accuracy_top5 = 0.55476254, metrics-code_transformer_preproc/targets/approx_bleu_score = 0.37589526, metrics-code_transformer_preproc/targets/neg_log_perplexity = -3.866674, metrics-code_transformer_preproc/targets/rouge_2_fscore = 0.1865434, metrics-code_transformer_preproc/targets/rouge_L_fscore = 0.5585525
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 314000: ./output/model.ckpt-314000
# INFO:tensorflow:global_step/sec: 0.693036
# INFO:tensorflow:loss = 2.5275714, step = 314000 (144.292 sec)
# INFO:tensorflow:global_step/sec: 1.20568
# INFO:tensorflow:loss = 3.8476367, step = 314100 (82.942 sec)
# INFO:tensorflow:global_step/sec: 1.11858
# INFO:tensorflow:loss = 3.7647104, step = 314200 (89.399 sec)
# INFO:tensorflow:global_step/sec: 1.12742
# INFO:tensorflow:loss = 2.6136174, step = 314300 (88.698 sec)
# INFO:tensorflow:global_step/sec: 1.20531
# INFO:tensorflow:loss = 3.3652713, step = 314400 (82.967 sec)
# INFO:tensorflow:global_step/sec: 1.12095
# INFO:tensorflow:loss = 4.5907574, step = 314500 (89.210 sec)
# INFO:tensorflow:global_step/sec: 1.12147
# INFO:tensorflow:loss = 2.0155182, step = 314600 (89.169 sec)
# INFO:tensorflow:global_step/sec: 1.2073
# INFO:tensorflow:loss = 3.4348269, step = 314700 (82.829 sec)
# INFO:tensorflow:global_step/sec: 1.10428
# INFO:tensorflow:loss = 2.2611704, step = 314800 (90.557 sec)
# INFO:tensorflow:global_step/sec: 1.11109
# INFO:tensorflow:loss = 3.0393357, step = 314900 (90.002 sec)
# INFO:tensorflow:Saving checkpoints for 315000 into ./output/model.ckpt.
# :::MLPv0.5.0 transformer 1560238177.101620913 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/problem.py:759) input_max_length: 1024
# INFO:tensorflow:Reading data files from ./data/code_transformer_preproc-dev*
# INFO:tensorflow:partition: 0 num_data_files: 1
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Setting T2TModel mode to 'eval'
# INFO:tensorflow:Setting hparams.layer_prepostprocess_dropout to 0.0
# INFO:tensorflow:Setting hparams.symbol_dropout to 0.0
# INFO:tensorflow:Setting hparams.label_smoothing to 0.0
# INFO:tensorflow:Setting hparams.dropout to 0.0
# :::MLPv0.5.0 transformer 1560238178.011909962 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/t2t_model.py:228) model_hp_initializer_gain: 1.0
# INFO:tensorflow:Using variable initializer: uniform_unit_scaling
# INFO:tensorflow:Transforming feature 'inputs' with symbol_modality_8105_128.bottom
# INFO:tensorflow:Transforming feature 'targets' with symbol_modality_8105_128.targets_bottom
# INFO:tensorflow:Building model body
# INFO:tensorflow:Transforming body output with symbol_modality_8105_128.top
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-11T07:29:40Z
# INFO:tensorflow:Graph was finalized.
# 2019-06-11 07:29:40.468845: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-06-11 07:29:40.468959: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-11 07:29:40.468985: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-06-11 07:29:40.469002: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-06-11 07:29:40.469303: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10869 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# INFO:tensorflow:Restoring parameters from ./output/model.ckpt-315000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-11-07:30:34
# INFO:tensorflow:Saving dict for global step 315000: global_step = 315000, loss = 3.8657444, metrics-code_transformer_preproc/targets/accuracy = 0.35812974, metrics-code_transformer_preproc/targets/accuracy_per_sequence = 0.004255319, metrics-code_transformer_preproc/targets/accuracy_top5 = 0.55366457, metrics-code_transformer_preproc/targets/approx_bleu_score = 0.3749244, metrics-code_transformer_preproc/targets/neg_log_perplexity = -3.8582706, metrics-code_transformer_preproc/targets/rouge_2_fscore = 0.18649873, metrics-code_transformer_preproc/targets/rouge_L_fscore = 0.5587023
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 315000: ./output/model.ckpt-315000
# INFO:tensorflow:global_step/sec: 0.672557
# INFO:tensorflow:loss = 2.9434874, step = 315000 (148.686 sec)
# INFO:tensorflow:global_step/sec: 1.0962
# INFO:tensorflow:loss = 3.9951537, step = 315100 (91.224 sec)
# INFO:tensorflow:global_step/sec: 1.04007
# INFO:tensorflow:loss = 5.7631335, step = 315200 (96.148 sec)
# INFO:tensorflow:global_step/sec: 1.1037
# INFO:tensorflow:loss = 2.348514, step = 315300 (90.604 sec)
# INFO:tensorflow:global_step/sec: 1.11816
# INFO:tensorflow:loss = 3.0715432, step = 315400 (89.434 sec)
# INFO:tensorflow:global_step/sec: 1.19072
# INFO:tensorflow:loss = 2.7557545, step = 315500 (83.981 sec)
# INFO:tensorflow:global_step/sec: 1.09224
# INFO:tensorflow:loss = 3.0842404, step = 315600 (91.555 sec)
# INFO:tensorflow:global_step/sec: 1.15567
# INFO:tensorflow:loss = 2.333234, step = 315700 (86.530 sec)
# INFO:tensorflow:global_step/sec: 1.28646
# INFO:tensorflow:loss = 0.09302306, step = 315800 (77.733 sec)
# INFO:tensorflow:global_step/sec: 1.21645
# INFO:tensorflow:loss = 3.387987, step = 315900 (82.206 sec)
# INFO:tensorflow:Saving checkpoints for 316000 into ./output/model.ckpt.
# :::MLPv0.5.0 transformer 1560239112.875565052 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/problem.py:759) input_max_length: 1024
# INFO:tensorflow:Reading data files from ./data/code_transformer_preproc-dev*
# INFO:tensorflow:partition: 0 num_data_files: 1
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Setting T2TModel mode to 'eval'
# INFO:tensorflow:Setting hparams.layer_prepostprocess_dropout to 0.0
# INFO:tensorflow:Setting hparams.symbol_dropout to 0.0
# INFO:tensorflow:Setting hparams.label_smoothing to 0.0
# INFO:tensorflow:Setting hparams.dropout to 0.0
# :::MLPv0.5.0 transformer 1560239113.800884008 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/t2t_model.py:228) model_hp_initializer_gain: 1.0
# INFO:tensorflow:Using variable initializer: uniform_unit_scaling
# INFO:tensorflow:Transforming feature 'inputs' with symbol_modality_8105_128.bottom
# INFO:tensorflow:Transforming feature 'targets' with symbol_modality_8105_128.targets_bottom
# INFO:tensorflow:Building model body
# INFO:tensorflow:Transforming body output with symbol_modality_8105_128.top
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-11T07:45:15Z
# INFO:tensorflow:Graph was finalized.
# 2019-06-11 07:45:16.085679: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-06-11 07:45:16.085793: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-11 07:45:16.085819: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-06-11 07:45:16.085834: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-06-11 07:45:16.086140: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10869 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# INFO:tensorflow:Restoring parameters from ./output/model.ckpt-316000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-11-07:46:11
# INFO:tensorflow:Saving dict for global step 316000: global_step = 316000, loss = 3.8696444, metrics-code_transformer_preproc/targets/accuracy = 0.35666576, metrics-code_transformer_preproc/targets/accuracy_per_sequence = 0.004255319, metrics-code_transformer_preproc/targets/accuracy_top5 = 0.5532986, metrics-code_transformer_preproc/targets/approx_bleu_score = 0.3764475, metrics-code_transformer_preproc/targets/neg_log_perplexity = -3.8642259, metrics-code_transformer_preproc/targets/rouge_2_fscore = 0.19138423, metrics-code_transformer_preproc/targets/rouge_L_fscore = 0.55908287
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 316000: ./output/model.ckpt-316000
# INFO:tensorflow:global_step/sec: 0.681331
# INFO:tensorflow:loss = 2.8386247, step = 316000 (146.773 sec)
# INFO:tensorflow:global_step/sec: 1.06883
# INFO:tensorflow:loss = 2.1830819, step = 316100 (93.559 sec)
# INFO:tensorflow:global_step/sec: 1.18531
# INFO:tensorflow:loss = 3.72729, step = 316200 (84.366 sec)
# INFO:tensorflow:global_step/sec: 1.1127
# INFO:tensorflow:loss = 3.5670342, step = 316300 (89.872 sec)
# INFO:tensorflow:global_step/sec: 1.02057
# INFO:tensorflow:loss = 3.220596, step = 316400 (97.984 sec)
# INFO:tensorflow:global_step/sec: 1.29408
# INFO:tensorflow:loss = 3.4067569, step = 316500 (77.275 sec)
# INFO:tensorflow:global_step/sec: 1.23253
# INFO:tensorflow:loss = 3.6508293, step = 316600 (81.134 sec)
# INFO:tensorflow:global_step/sec: 1.26111
# INFO:tensorflow:loss = 2.0924573, step = 316700 (79.295 sec)
# INFO:tensorflow:global_step/sec: 1.12843
# INFO:tensorflow:loss = 2.7350335, step = 316800 (88.619 sec)
# INFO:tensorflow:global_step/sec: 1.21113
# INFO:tensorflow:loss = 3.3928227, step = 316900 (82.567 sec)
# Traceback (most recent call last):
#   File "/usr/local/bin/t2t-trainer", line 33, in <module>
#     tf.app.run()
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/platform/app.py", line 125, in run
#     _sys.exit(main(argv))
#   File "/usr/local/bin/t2t-trainer", line 28, in main
#     t2t_trainer.main(argv)
#   File "/usr/local/lib/python2.7/dist-packages/tensor2tensor/bin/t2t_trainer.py", line 387, in main
#     execute_schedule(exp)
#   File "/usr/local/lib/python2.7/dist-packages/tensor2tensor/bin/t2t_trainer.py", line 349, in execute_schedule
#     getattr(exp, FLAGS.schedule)()
#   File "/usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/trainer_lib.py", line 438, in continuous_train_and_eval
#     self._eval_spec)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow_estimator/python/estimator/training.py", line 471, in train_and_evaluate
#     return executor.run()
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow_estimator/python/estimator/training.py", line 611, in run
#     return self.run_local()
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow_estimator/python/estimator/training.py", line 712, in run_local
#     saving_listeners=saving_listeners)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow_estimator/python/estimator/estimator.py", line 358, in train
#     loss = self._train_model(input_fn, hooks, saving_listeners)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow_estimator/python/estimator/estimator.py", line 1124, in _train_model
#     return self._train_model_default(input_fn, hooks, saving_listeners)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow_estimator/python/estimator/estimator.py", line 1158, in _train_model_default
#     saving_listeners)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow_estimator/python/estimator/estimator.py", line 1407, in _train_with_estimator_spec
#     _, loss = mon_sess.run([estimator_spec.train_op, estimator_spec.loss])
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/training/monitored_session.py", line 676, in run
#     run_metadata=run_metadata)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/training/monitored_session.py", line 1171, in run
#     run_metadata=run_metadata)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/training/monitored_session.py", line 1255, in run
#     return self._sess.run(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/training/monitored_session.py", line 1327, in run
#     run_metadata=run_metadata)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/training/monitored_session.py", line 1091, in run
#     return self._sess.run(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.py", line 929, in run
#     run_metadata_ptr)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.py", line 1152, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.py", line 1328, in _do_run
#     run_metadata)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.py", line 1334, in _do_call
#     return fn(*args)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.py", line 1319, in _run_fn
#     options, feed_dict, fetch_list, target_list, run_metadata)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.py", line 1407, in _call_tf_sessionrun
#     run_metadata)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-9b6bf55ff1a3> in <module>()
# ----> 1 get_ipython().system("t2t-trainer --generate_data --t2t_usr_dir=./transformer_preproc --data_dir=./data --output_dir=./output --problem=code_transformer_preproc --model=lstm_seq2seq --hparams_set=lstm_seq2seq --hparams='batch_size=1024' --keep_checkpoint_max=1 --train_steps=720000")
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      72       kwargs.update({'also_return_output': True})
#      73
# ---> 74     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#      75
#      76     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     436   # stack.
#     437   result = _run_command(
# --> 438       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
#     439   shell.user_ns['_exit_code'] = result.returncode
#     440   if -result.returncode in _INTERRUPTED_SIGNALS:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     193       os.close(child_pty)
#     194
# --> 195       return _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     196   finally:
#     197     epoll.close()
#
# /usr/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      86         if type is None:
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#      90                 return False
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _display_stdin_widget(delay_millis)
#     353
#     354   hide_args = ['cell_remove_stdin', {}]
# --> 355   _message.blocking_request(*hide_args, parent=shell.parent_header)
#     356
#     357
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     169   # unique.
#     170   request_id = send_request(request_type, request, parent=parent)
# --> 171   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %% [markdown]
# # Upload trained model to drive

# %%
import shutil
# !zip -r ./model13.zip ./output
shutil.move("./model13.zip", "/content/drive/My Drive")
drive.mount('/content/drive', force_remount=True)
# Out:
#   adding: output/ (stored 0%)
#   adding: output/events.out.tfevents.1560198226.4f4bcf4999eb (deflated 95%)
#   adding: output/model.ckpt-316000.index (deflated 58%)
#   adding: output/events.out.tfevents.1559823069.306770c51666 (deflated 95%)
#   adding: output/events.out.tfevents.1559564653.d3795f2f3185 (deflated 94%)
#   adding: output/model.ckpt-316000.data-00001-of-00002 (deflated 14%)
#   adding: output/model.ckpt-316000.meta (deflated 94%)
#   adding: output/eval/ (stored 0%)
#   adding: output/eval/events.out.tfevents.1559633038.9caa77013cec (deflated 98%)
#   adding: output/eval/events.out.tfevents.1559650193.9caa77013cec (deflated 98%)
#   adding: output/eval/events.out.tfevents.1559565274.d3795f2f3185 (deflated 93%)
#   adding: output/eval/events.out.tfevents.1559721298.c2f81932b7cb (deflated 98%)
#   adding: output/eval/events.out.tfevents.1559895989.8f5e0af1a077 (deflated 98%)
#   adding: output/eval/events.out.tfevents.1560198791.4f4bcf4999eb (deflated 96%)
#   adding: output/eval/events.out.tfevents.1560153938.4eb99f03d590 (deflated 98%)
#   adding: output/eval/events.out.tfevents.1560071741.f9bb4b183132 (deflated 98%)
#   adding: output/eval/events.out.tfevents.1560237244.fee8b0a59ca1 (deflated 95%)
#   adding: output/eval/events.out.tfevents.1559939925.df0da9fd69ae (deflated 96%)
#   adding: output/eval/events.out.tfevents.1559823630.306770c51666 (deflated 97%)
#   adding: output/graph.pbtxt (deflated 97%)
#   adding: output/hparams.json (deflated 66%)
#   adding: output/checkpoint (deflated 43%)
#   adding: output/events.out.tfevents.1559649585.9caa77013cec (deflated 95%)
#   adding: output/events.out.tfevents.1559632450.9caa77013cec (deflated 95%)
#   adding: output/events.out.tfevents.1560153367.4eb99f03d590 (deflated 95%)
#   adding: output/events.out.tfevents.1559895377.8f5e0af1a077 (deflated 95%)
#   adding: output/flags.txt (deflated 56%)
#   adding: output/flags_t2t.txt (deflated 54%)
#   adding: output/events.out.tfevents.1560236352.fee8b0a59ca1 (deflated 95%)
#   adding: output/events.out.tfevents.1560071191.f9bb4b183132 (deflated 95%)
#   adding: output/events.out.tfevents.1559720772.c2f81932b7cb (deflated 95%)
#   adding: output/model.ckpt-316000.data-00000-of-00002 (deflated 46%)
#   adding: output/events.out.tfevents.1559939385.df0da9fd69ae (deflated 95%)
# Mounted at /content/drive

# %%
# !ls -lh
# Out:
# total 57M
# drwxr-xr-x 2 root root  20K May 20 13:10 data
# -rw-r--r-- 1 root root  57M May 20 13:02 data.7z
# drwxr-xr-x 3 root root 4.0K May 20 13:02 Evaluation
# drwxr-xr-x 2 root root 4.0K May 20 13:02 models
# drwxr-xr-x 3 root root 4.0K May 20 20:01 output
# -rw-r--r-- 1 root root 1.8K May 20 13:02 prepare_transformer_data.py
# drwxr-xr-x 2 root root 4.0K May 20 13:02 preprocess
# -rw-r--r-- 1 root root  112 May 20 13:02 readme.md
# drwxr-xr-x 4 root root 4.0K May 20 13:10 tmp
# drwxr-xr-x 2 root root 4.0K May 20 13:02 transformer
# drwxr-xr-x 2 root root 4.0K May 20 13:03 transformer_data
# drwxr-xr-x 2 root root 4.0K May 20 13:03 transformer_preproc
# -rw-r--r-- 1 root root  573 May 20 13:11 url.txt

# %% [markdown]
# # Run decoder

# %%
# !t2t-decoder --t2t_usr_dir=./transformer_preproc --data_dir=./data --output_dir=./output --problem=code_transformer_preproc --model=lstm_seq2seq --hparams_set=lstm_seq2seq --hparams='batch_size=1024' --decode_hparams="beam_size=4,alpha=0.6" --decode_from_file="./sampled.cd" --decode_to_file="./sampled_model.en"
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# INFO:tensorflow:Importing user module transformer_preproc from path /content/Deep-Learning
# INFO:tensorflow:Overriding hparams in lstm_seq2seq with batch_size=1024
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/trainer_lib.py:278: __init__ (from tensorflow.contrib.learn.python.learn.estimators.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.RunConfig instead.
# INFO:tensorflow:Configuring DataParallelism to replicate the model.
# INFO:tensorflow:schedule=continuous_train_and_eval
# INFO:tensorflow:worker_gpu=1
# INFO:tensorflow:sync=False
# WARNING:tensorflow:Schedule=continuous_train_and_eval. Assuming that training is running on a single machine.
# INFO:tensorflow:datashard_devices: ['gpu:0']
# INFO:tensorflow:caching_devices: None
# INFO:tensorflow:ps_devices: ['gpu:0']
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': None, '_num_ps_replicas': 0, '_keep_checkpoint_max': 20, '_task_type': None, '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f37eab4f150>, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_protocol': None, '_save_checkpoints_steps': 1000, '_keep_checkpoint_every_n_hours': 10000, '_session_config': gpu_options {
#   per_process_gpu_memory_fraction: 0.95
# }
# allow_soft_placement: true
# graph_options {
#   optimizer_options {
#     global_jit_level: OFF
#   }
# }
# , '_model_dir': './output', 'use_tpu': False, '_tf_random_seed': None, '_master': '', '_device_fn': None, '_num_worker_replicas': 0, '_task_id': 0, '_log_step_count_steps': 100, '_evaluation_master': '', '_eval_distribute': None, 'data_parallelism': <tensor2tensor.utils.expert_utils.Parallelism object at 0x7f37eab4f190>, '_environment': 'local', '_save_summary_steps': 100, 't2t_device_info': {'num_async_replicas': 1}}
# WARNING:tensorflow:Estimator's model_fn (<function wrapping_model_fn at 0x7f37eb422de8>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:decode_hp.batch_size not specified; default=32
# INFO:tensorflow:Performing decoding from file (./sampled.cd).
# INFO:tensorflow:Getting sorted inputs
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow: batch 16
# INFO:tensorflow:Decoding batch 0
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/decoding.py:525: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, use
#     tf.py_function, which takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/decoding.py:821: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:Input graph does not use tf.data.Dataset or contain a QueueRunner. That means predict yields forever. This is probably a mistake.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Setting T2TModel mode to 'infer'
# INFO:tensorflow:Setting hparams.layer_prepostprocess_dropout to 0.0
# INFO:tensorflow:Setting hparams.symbol_dropout to 0.0
# INFO:tensorflow:Setting hparams.label_smoothing to 0.0
# INFO:tensorflow:Setting hparams.dropout to 0.0
# INFO:tensorflow:Beam Decoding with beam size 4
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/beam_search.py:727: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# :::MLPv0.5.0 transformer 1560240890.594532967 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/t2t_model.py:228) model_hp_initializer_gain: 1.0
# INFO:tensorflow:Using variable initializer: uniform_unit_scaling
# INFO:tensorflow:Transforming feature 'inputs' with symbol_modality_8105_128.bottom
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/function.py:1007: calling create_op (from tensorflow.python.framework.ops) with compute_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# Shapes are always computed; don't use the compute_shapes as it has no effect.
# INFO:tensorflow:Transforming feature 'targets' with symbol_modality_8105_128.targets_bottom
# INFO:tensorflow:Building model body
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/models/lstm.py:33: __init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/models/lstm.py:61: __init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensor2tensor/models/lstm.py:66: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/rnn_cell_impl.py:1259: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# INFO:tensorflow:Transforming body output with symbol_modality_8105_128.top
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# 2019-06-11 08:14:51.878100: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-06-11 08:14:51.878524: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x56076ddb4d60 executing computations on platform Host. Devices:
# 2019-06-11 08:14:51.878568: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-06-11 08:14:51.986186: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-11 08:14:51.986819: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x56076ddb5700 executing computations on platform CUDA. Devices:
# 2019-06-11 08:14:51.986860: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-06-11 08:14:51.987264: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-06-11 08:14:51.987302: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-06-11 08:14:52.414722: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-11 08:14:52.414811: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-06-11 08:14:52.414831: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-06-11 08:14:52.415123: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-06-11 08:14:52.415190: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10869 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./output/model.ckpt-316000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 2019-06-11 08:14:52.896414: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# INFO:tensorflow:Inference results INPUT: public void readByteArray(byte[] arr,int offset) throws InvalidDataTypeException {\n  if (arr == null) {\n    throw new NullPointerException(\"Byte array is null\");\n  }\n  if ((offset < 0) || (offset >= arr.length)) {\n    throw new InvalidDataTypeException(\"Offset to byte array is out of bounds: offset = \" + offset + \", array.length = \"+ arr.length);\n  }\n  if (offset + size > arr.length) {\n    throw new InvalidDataTypeException(\"Offset plus size to byte array is out of bounds: offset = \" + offset + \", size = \"+ size+ \" + arr.length \"+ arr.length);\n  }\n  long lvalue=0;\n  for (int i=offset; i < (offset + size); i++) {\n    lvalue<<=8;\n    lvalue+=(arr[i] & 0xff);\n  }\n  value=lvalue;\n  logger.config(\"Read NumberFixedlength:\" + value);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Reads an array of bytes from a byte array.
# INFO:tensorflow:Inference results INPUT: private static byte[] procIPv4Addr(String addrStr,BitSet wildCardBitSet,String expr) throws AciException {\n  byte[] addrBytes=new byte[IN4ADDRSZ];\n  String[] s=addrStr.split(\"\\.\",-1);\n  try {\n    if (s.length != IN4ADDRSZ) {\n      LocalizableMessage message=WARN_ACI_SYNTAX_INVALID_IPV4_FORMAT.get(expr);\n      throw new AciException(message);\n    }\n    for (int i=0; i < IN4ADDRSZ; i++) {\n      String quad=s[i].trim();\n      if (quad.equals(\"*\")) {\n        wildCardBitSet.set(i);\n      }\n else {\n        long val=Integer.parseInt(quad);\n        if (val < 0 || val > 0xff) {\n          LocalizableMessage message=WARN_ACI_SYNTAX_INVALID_IPV4_VALUE.get(expr);\n          throw new AciException(message);\n        }\n        addrBytes[i]=(byte)(val & 0xff);\n      }\n    }\n  }\n catch (  NumberFormatException nfex) {\n    LocalizableMessage message=WARN_ACI_SYNTAX_IPV4_NOT_NUMERIC.get(expr);\n    throw new AciException(message);\n  }\n  return addrBytes;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Helper method to check whether the given pattern is a valid address.
# INFO:tensorflow:Inference results INPUT: public int doFinal(byte[] out,int outOff) throws DataLengthException, IllegalStateException, InvalidCipherTextException {\n  int blockSize=cipher.getBlockSize();\n  int resultLen=0;\n  if (forEncryption) {\n    if (bufOff == blockSize) {\n      if ((outOff + 2 * blockSize) > out.length) {\n        reset();\n        throw new OutputLengthException(\"output buffer too short\");\n      }\n      resultLen=cipher.processBlock(buf,0,out,outOff);\n      bufOff=0;\n    }\n    padding.addPadding(buf,bufOff);\n    resultLen+=cipher.processBlock(buf,0,out,outOff + resultLen);\n    reset();\n  }\n else {\n    if (bufOff == blockSize) {\n      resultLen=cipher.processBlock(buf,0,buf,0);\n      bufOff=0;\n    }\n else {\n      reset();\n      throw new DataLengthException(\"last block incomplete in decryption\");\n    }\n    try {\n      resultLen-=padding.padCount(buf);\n      System.arraycopy(buf,0,out,outOff,resultLen);\n    }\n  finally {\n      reset();\n    }\n  }\n  return resultLen;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Process the next block.
# INFO:tensorflow:Inference results INPUT: public List<VerificationOK> verify(X509Certificate signCert,X509Certificate issuerCert,Date signDate) throws GeneralSecurityException, IOException {\n  List<VerificationOK> result=new ArrayList<>();\n  int validCrlsFound=0;\n  if (crls != null) {\n    for (    X509CRL crl : crls) {\n      if (verify(crl,signCert,issuerCert,signDate))       validCrlsFound++;\n    }\n  }\n  boolean online=false;\n  if (onlineCheckingAllowed && validCrlsFound == 0) {\n    if (verify(getCRL(signCert,issuerCert),signCert,issuerCert,signDate)) {\n      validCrlsFound++;\n      online=true;\n    }\n  }\n  LOGGER.info(\"Valid CRLs found: \" + validCrlsFound);\n  if (validCrlsFound > 0) {\n    result.add(new VerificationOK(signCert,this.getClass(),\"Valid CRLs found: \" + validCrlsFound + (online ? \" (online)\" : \"\")));\n  }\n  if (verifier != null)   result.addAll(verifier.verify(signCert,issuerCert,signDate));\n  return result;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Verify that the given certificate is valid.
# INFO:tensorflow:Inference results INPUT: int readUtah(int row,int column,int numRows,int numColumns){\n  int currentByte=0;\n  if (readModule(row - 2,column - 2,numRows,numColumns)) {\n    currentByte|=1;\n  }\n  currentByte<<=1;\n  if (readModule(row - 2,column - 1,numRows,numColumns)) {\n    currentByte|=1;\n  }\n  currentByte<<=1;\n  if (readModule(row - 1,column - 2,numRows,numColumns)) {\n    currentByte|=1;\n  }\n  currentByte<<=1;\n  if (readModule(row - 1,column - 1,numRows,numColumns)) {\n    currentByte|=1;\n  }\n  currentByte<<=1;\n  if (readModule(row - 1,column,numRows,numColumns)) {\n    currentByte|=1;\n  }\n  currentByte<<=1;\n  if (readModule(row,column - 2,numRows,numColumns)) {\n    currentByte|=1;\n  }\n  currentByte<<=1;\n  if (readModule(row,column - 1,numRows,numColumns)) {\n    currentByte|=1;\n  }\n  currentByte<<=1;\n  if (readModule(row,column,numRows,numColumns)) {\n    currentByte|=1;\n  }\n  return currentByte;\n}\n
# INFO:tensorflow:Inference results OUTPUT: <p>reads the 8 bits of the given byte array.
# INFO:tensorflow:Inference results INPUT: @Override public String toString(){\n  StringBuilder b=new StringBuilder(64);\n  b.append(\"name = \" + name + \" \");\n  b.append(\"type = \" + type + \" \");\n  b.append(\"reqTime = \" + reqTime + \" \");\n  b.append(\"required = \" + required + \" \");\n  b.append(\"fragment = \" + fragment + \" \");\n  b.append(\"deferredValue = \" + deferredValue + \" \");\n  b.append(\"expectedTypeName = \" + expectedTypeName + \" \");\n  b.append(\"deferredMethod = \" + deferredMethod + \" \");\n  b.append(\"methodSignature = \" + methodSignature);\n  return b.toString();\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns a string representation of this object.
# INFO:tensorflow:Inference results INPUT: public Goomba genGoomba(float[] coords,int stageZone,boolean checkBlocks){\n  return new Goomba(stageContainer,gameLoop,player,stageZone,checkBlocks,new String[]{null,\"M \" + ASPECT_LENGTH + \",0 L \"+ ASPECT_LENGTH+ \",\"+ (ASPECT_LENGTH - 6),\"M 0,\" + ASPECT_LENGTH + \" L \"+ ASPECT_LENGTH+ \",\"+ ASPECT_LENGTH,\"M 0,0 L 0,\" + (ASPECT_LENGTH - 6),\"M 20,\" + (ASPECT_LENGTH - 1) + \" L \"+ (ASPECT_LENGTH - 20)+ \",\"+ (ASPECT_LENGTH - 1),\"M 0,0 L 0,0 \" + ASPECT_LENGTH + \",0 \"+ ASPECT_LENGTH+ \",\"+ ASPECT_LENGTH+ \" 0,\"+ ASPECT_LENGTH+ \" Z\"},coords[0],coords[1] - ASPECT_LENGTH,0.4f * REL_HEIGHT,4.9f * REL_HEIGHT,playerDeathSprites,goomba0,goomba1,goomba2,goomba3);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Generates a new instance of the given string.
# INFO:tensorflow:Inference results INPUT: protected void cdata(char ch[],int start,final int length) throws org.xml.sax.SAXException {\n  try {\n    final int old_start=start;\n    if (m_elemContext.m_startTagOpen) {\n      closeStartTag();\n      m_elemContext.m_startTagOpen=false;\n    }\n    m_ispreserve=true;\n    if (shouldIndent())     indent();\n    boolean writeCDataBrackets=(((length >= 1) && escapingNotNeeded(ch[start])));\n    if (writeCDataBrackets && !m_cdataTagOpen) {\n      m_writer.write(CDATA_DELIMITER_OPEN);\n      m_cdataTagOpen=true;\n    }\n    if (isEscapingDisabled()) {\n      charactersRaw(ch,start,length);\n    }\n else     writeNormalizedChars(ch,start,length,true,m_lineSepUse);\n    if (writeCDataBrackets) {\n      if (ch[start + length - 1] == \']\')       closeCDATA();\n    }\n    if (m_tracer != null)     super.fireCDATAEvent(ch,old_start,length);\n  }\n catch (  IOException ioe) {\n    throw new org.xml.sax.SAXException(Utils.messages.createMessage(MsgKey.ER_OIERROR,null),ioe);\n  }\n}\n
# INFO:tensorflow:Inference results OUTPUT: Receive notification of the end of an element.
# INFO:tensorflow:Inference results INPUT: public final void testReadbyteArrayintint02() throws IOException {\n  assertEquals(0,MY_MESSAGE_LEN % CHUNK_SIZE);\n  for (int ii=0; ii < algorithmName.length; ii++) {\n    try {\n      MessageDigest md=MessageDigest.getInstance(algorithmName[ii]);\n      InputStream is=new ByteArrayInputStream(myMessage);\n      DigestInputStream dis=new DigestInputStream(is,md);\n      byte[] bArray=new byte[MY_MESSAGE_LEN];\n      for (int i=0; i < MY_MESSAGE_LEN / CHUNK_SIZE; i++) {\n        assertTrue(\"retval\",dis.read(bArray,i * CHUNK_SIZE,CHUNK_SIZE) == CHUNK_SIZE);\n      }\n      assertTrue(\"bArray\",Arrays.equals(myMessage,bArray));\n      assertTrue(\"update\",Arrays.equals(dis.getMessageDigest().digest(),MDGoldenData.getDigest(algorithmName[ii])));\n      return;\n    }\n catch (    NoSuchAlgorithmException e) {\n    }\n  }\n  fail(getName() + \": no MessageDigest algorithms available - test not performed\");\n}\n
# INFO:tensorflow:Inference results OUTPUT: Test for <code>getbyte()</code> method.
# INFO:tensorflow:Inference results INPUT: public static void addAttributeToSchema(ServiceSchema serviceSchema,Node attributeSchemaNode) throws UpgradeException {\n  String classMethod=\"UpgradeUtils:addAttributeToSchema: \";\n  if (debug.messageEnabled()) {\n    debug.message(classMethod + \"Adding attributeschema :\" + \"for service :\"+ serviceSchema.getName());\n  }\n  ByteArrayInputStream bis=null;\n  try {\n    bis=new ByteArrayInputStream(XMLUtils.print(attributeSchemaNode).getBytes());\n    serviceSchema.addAttributeSchema(bis);\n  }\n catch (  SMSException sme) {\n    debug.error(classMethod + \"Cannot add attribute schema for \" + serviceSchema.getName(),sme);\n    throw new UpgradeException(sme.getMessage());\n  }\ncatch (  SSOException ssoe) {\n    debug.error(classMethod + \"Invalid SSOToken : \",ssoe);\n    throw new UpgradeException(ssoe.getMessage());\n  }\n}\n
# INFO:tensorflow:Inference results OUTPUT: Adds the given key to the given name.
# INFO:tensorflow:Inference results INPUT: public static boolean isTargetApplicable(Aci aci,AciTargets targets,DN entryDN){\n  DN targetDN=aci.getDN();\n  Target target=targets.getTarget();\n  if (target != null && !target.isPattern() && target.getOperator() != NOT_EQUALITY) {\n    targetDN=target.getDN();\n  }\n  if (!isInScopeOf(entryDN,targetDN,targets.getTargetScope())) {\n    return false;\n  }\n  if (target != null) {\n    if (!target.isPattern() && target.getOperator() == NOT_EQUALITY && entryDN.isSubordinateOrEqualTo(target.getDN())) {\n      return false;\n    }\n    if (target.isPattern()) {\n      final boolean ret=target.matchesPattern(entryDN);\n      if (target.getOperator() == NOT_EQUALITY) {\n        return !ret;\n      }\n      return ret;\n    }\n  }\n  return true;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns true if the given name is a valid pattern.
# INFO:tensorflow:Inference results INPUT: @Override public String generateName(final IntUnaryOperator randomInRange,final int length){\n  if (length == 0) {\n    return \"LENGTH_WAS_ZERO\";\n  }\n  final StringBuilder sb=new StringBuilder();\n  final int initialSequenceIndex=randomInRange.applyAsInt(sequences.size());\n  final String initialSequence=sequences.get(initialSequenceIndex);\n  sb.append(initialSequence);\n  char previous=initialSequence.charAt(0);\n  char current=initialSequence.charAt(1);\n  for (int i=2; i < length; ++i) {\n    final String key=previous + \"\" + current;\n    try {\n      final char next=chooseNextCharacter(randomInRange,key);\n      sb.append(next);\n      previous=current;\n      current=next;\n    }\n catch (    final NoSuchElementException e) {\n      break;\n    }\n  }\n  return formatName(sb.toString());\n}\n
# INFO:tensorflow:Inference results OUTPUT: Generates a string for the given string.
# INFO:tensorflow:Inference results INPUT: public boolean isBearer(){\n  if (_statements == null || _statements.isEmpty()) {\n    return false;\n  }\n  Iterator iter=_statements.iterator();\n  while (iter.hasNext()) {\n    Object statement=iter.next();\n    if (!(statement instanceof SubjectStatement)) {\n      continue;\n    }\n    Subject subject=((SubjectStatement)statement).getSubject();\n    if (subject == null) {\n      continue;\n    }\n    SubjectConfirmation sc=subject.getSubjectConfirmation();\n    if (sc == null) {\n      continue;\n    }\n    Set confirmationMethods=sc.getConfirmationMethod();\n    if (confirmationMethods == null || confirmationMethods.isEmpty()) {\n      continue;\n    }\n    if (confirmationMethods.contains(SAMLConstants.CONFIRMATION_METHOD_BEARER)) {\n      return true;\n    }\n  }\n  return false;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns true if this method is not supported.
# INFO:tensorflow:Inference results INPUT: public void test_MultipleUpdatesInOneTables() throws SQLException {\n  int id=1;\n  String field=\"field3\";\n  String selectQuery=\"SELECT * FROM \" + DatabaseCreator.TEST_TABLE1 + \" WHERE id=\"+ id;\n  Statement statement=conn.createStatement();\n  ResultSet result=statement.executeQuery(selectQuery);\n  assertTrue(\"There is no records with id = \" + id,result.next());\n  result.close();\n  for (int i=0; i < numThreads; i++) {\n    threadPool.runTask(createTask7(id,field));\n  }\n  threadPool.join();\n  double expectedVal=id + numThreads;\n  result=statement.executeQuery(selectQuery);\n  assertTrue(\"There is no records with id = \" + id,result.next());\n  result.close();\n}\n
# INFO:tensorflow:Inference results OUTPUT: This method is called when a statement has been created.
# INFO:tensorflow:Inference results INPUT: public void archive(String fileName,String location){\n  if ((fileName == null) || (fileName.length() == 0)) {\n    Debug.error(\"Archiver:archive:FileName is null\");\n    return;\n  }\n else   if ((location == null) || (location.length() == 0)) {\n    Debug.error(\"Archiver:archive:Location is null\");\n    return;\n  }\n  Logger logger=(com.sun.identity.log.Logger)Logger.getLogger(fileName);\n  filesPerKeystoreCounter++;\n  Date d=newDate();\n  String timestampedFileName=location + PREFIX + fileName+ \".\"+ sdf.format(d).toString();\n  String completePath=location + PREFIX + fileName;\n  File f=new File(completePath);\n  f.renameTo(new File(timestampedFileName));\n  SecureFileHandler.addToCurrentFileList(fileName,fileName + \".\" + sdf.format(d).toString(),fileName);\n  return;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Remove a file.
# INFO:tensorflow:Inference results INPUT: @Override public boolean equals(Object o){\n  if (o == null) {\n    return false;\n  }\n  if (o == this) {\n    return true;\n  }\n  if (!(o instanceof SearchFilter)) {\n    return false;\n  }\n  SearchFilter f=(SearchFilter)o;\n  if (filterType != f.filterType) {\n    return false;\n  }\nswitch (filterType) {\ncase AND:\ncase OR:\n    return andOrEqual(f);\ncase NOT:\n  return notComponent.equals(f.notComponent);\ncase SUBSTRING:\nreturn substringEqual(f);\ncase PRESENT:\nreturn attributeDescription.equals(f.attributeDescription);\ncase EXTENSIBLE_MATCH:\nreturn extensibleEqual(f);\ncase EQUALITY:\ncase APPROXIMATE_MATCH:\ncase GREATER_OR_EQUAL:\ncase LESS_OR_EQUAL:\nreturn attributeDescription.equals(f.attributeDescription) && assertionValue.equals(f.assertionValue);\ndefault :\nreturn false;\n}\n}\n
# INFO:tensorflow:Inference results OUTPUT: Compares this object with the specified object.
# INFO:tensorflow:Inference results INPUT: static void storeServerList(Set servers,Map namingAttrs){\n  Set serverList=new HashSet();\n  Set siteList=new HashSet();\n  Iterator iter=servers.iterator();\n  while (iter.hasNext()) {\n    String serverEntry=(String)iter.next();\n    int index=serverEntry.indexOf(delimiter);\n    if (index != -1) {\n      String server=serverEntry.substring(0,index);\n      String serverId=serverEntry.substring(index + 1,serverEntry.length());\n      siteList.add(serverId);\n      index=serverId.indexOf(delimiter);\n      if (index != -1) {\n        serverId=serverId.substring(0,2);\n      }\n      HashSet serverSet=new HashSet();\n      serverSet.add(server);\n      serverList.add(server);\n      namingAttrs.put(serverId,serverSet);\n    }\n else {\n      namingDebug.error(\"Platform Server List entry is invalid:\" + serverEntry);\n    }\n  }\n  namingAttrs.put(Constants.PLATFORM_LIST,serverList);\n  namingAttrs.put(Constants.SITE_ID_LIST,siteList);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Put a list to the database.
# INFO:tensorflow:Inference results INPUT: private void processNotification(SessionNotification snot,boolean isLocal){\n  SessionInfo info=snot.getSessionInfo();\n  sessionDebug.message(\"SESSION NOTIFICATION : \" + info.toXMLString());\n  if (!info.getState().equals(\"valid\")) {\n    if (isLocal) {\n      sessionCache.removeLocalSID(info);\n    }\n else {\n      sessionCache.removeRemoteSID(info);\n    }\n    return;\n  }\n  SessionID sid=new SessionID(info.getSessionID());\n  Session session=sessionCache.readSession(sid);\n  try {\n    if (session == null) {\n      return;\n    }\n    session.update(info);\n  }\n catch (  Exception e) {\n    sessionDebug.error(\"SessionNotificationHandler:processNotification : \",e);\n    sessionCache.removeSID(sid);\n    return;\n  }\n  SessionEventType sessionEventType=SessionEventType.fromCode(snot.getNotificationType());\n  SessionEvent evt=new SessionEvent(session,sessionEventType,snot.getNotificationTime());\n  Session.invokeListeners(evt);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Process a notification.
# INFO:tensorflow:Inference results INPUT: public static boolean skip_scope(JflexScanner p_scanner){\n  int open_bracked_count=1;\n  while (open_bracked_count > 0) {\n    p_scanner.yybegin(DsnFileScanner.NAME);\n    Object curr_token=null;\n    try {\n      curr_token=p_scanner.next_token();\n    }\n catch (    Exception e) {\n      System.err.println(\"ScopeKeyword.skip_scope: Error while scanning file\");\n      System.err.println(e);\n      return false;\n    }\n    if (curr_token == null) {\n      return false;\n    }\n    if (curr_token == DsnKeyword.OPEN_BRACKET) {\n      ++open_bracked_count;\n    }\n else     if (curr_token == DsnKeyword.CLOSED_BRACKET) {\n      --open_bracked_count;\n    }\n  }\n  return true;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Attempts to parse a string.
# INFO:tensorflow:Inference results INPUT: public static int dehexchar(char hex){\n  if (hex >= \'0\' && hex <= \'9\') {\n    return hex - \'0\';\n  }\n else   if (hex >= \'A\' && hex <= \'F\') {\n    return hex - \'A\' + 10;\n  }\n else   if (hex >= \'a\' && hex <= \'f\') {\n    return hex - \'a\' + 10;\n  }\n else {\n    return -1;\n  }\n}\n
# INFO:tensorflow:Inference results OUTPUT: Converts a byte array to a string.
# INFO:tensorflow:Inference results INPUT: public boolean validateFileFormat(Path location,Configuration conf){\n  FileSystem fileSystem;\n  try {\n    fileSystem=FileSystem.get(location.toUri(),conf);\n    FileStatus[] items=fileSystem.listStatus(location);\n    for (    FileStatus item : items) {\n      if (item.getPath().getName().startsWith(\"_\")) {\n        continue;\n      }\n else       if (item.getPath().getName().contains(\".avro\")) {\n        logger.debug(item.getPath().getName());\n        logger.info(\"Created File format is AVRO !\");\n        return true;\n      }\n else       logger.debug(item.getPath().getName());\n      logger.error(\"Created File Format is not correct\");\n    }\n  }\n catch (  IOException e) {\n    logger.trace(e.getMessage());\n  }\n  return false;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Validate file.
# INFO:tensorflow:Inference results INPUT: static int applyMaskPenaltyRule4(ByteMatrix matrix){\n  int numDarkCells=0;\n  byte[][] array=matrix.getArray();\n  int width=matrix.getWidth();\n  int height=matrix.getHeight();\n  for (int y=0; y < height; y++) {\n    byte[] arrayY=array[y];\n    for (int x=0; x < width; x++) {\n      if (arrayY[x] == 1) {\n        numDarkCells++;\n      }\n    }\n  }\n  int numTotalCells=matrix.getHeight() * matrix.getWidth();\n  int fivePercentVariances=Math.abs(numDarkCells * 2 - numTotalCells) * 10 / numTotalCells;\n  return fivePercentVariances * N4;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Applies the size of the matrix to the given size.
# INFO:tensorflow:Inference results INPUT: public void invokeAndWait(Runnable task){\n  if (roomLock.isHeldByCurrentThread()) {\n    if (cachedRunnables == null) {\n      cachedRunnables=new ArrayList<>();\n    }\n    cachedRunnables.add(task);\n  }\n else {\n    roomLock.lock();\n    try {\n      cachedRunnables=null;\n      if (!closed) {\n        task.run();\n      }\n      if (cachedRunnables != null) {\n        for (int i=0; i < cachedRunnables.size(); i++) {\n          if (!closed) {\n            cachedRunnables.get(i).run();\n          }\n        }\n        cachedRunnables=null;\n      }\n    }\n  finally {\n      roomLock.unlock();\n    }\n  }\n}\n
# INFO:tensorflow:Inference results OUTPUT: Invokes the method that can be invoked by the event.
# INFO:tensorflow:Inference results INPUT: public PluginResult.PostResponse invokePostResponseSearchPlugins(PostResponseSearchOperation searchOperation){\n  PluginResult.PostResponse result=null;\n  for (  DirectoryServerPlugin p : postResponseSearchPlugins) {\n    if (isInternalOperation(searchOperation,p)) {\n      continue;\n    }\n    try {\n      result=p.doPostResponse(searchOperation);\n    }\n catch (    Exception e) {\n      logException(searchOperation,p,e,ERR_PLUGIN_POST_RESPONSE_PLUGIN_EXCEPTION);\n    }\n    if (result == null) {\n      logNullResult(searchOperation,p,ERR_PLUGIN_POST_RESPONSE_PLUGIN_RETURNED_NULL);\n    }\n else     if (!result.continuePluginProcessing()) {\n      return result;\n    }\n  }\n  if (result == null) {\n    result=PluginResult.PostResponse.continueOperationProcessing();\n  }\n  return result;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Invokes the request for the given request.
# INFO:tensorflow:Inference results INPUT: public DN child(final DN dn){\n  Reject.ifNull(dn);\n  if (dn.isRootDN()) {\n    return this;\n  }\n else   if (isRootDN()) {\n    return dn;\n  }\n else {\n    final RDN[] rdns=new RDN[dn.size()];\n    int i=rdns.length;\n    for (DN next=dn; next.rdn != null; next=next.parent) {\n      rdns[--i]=next.rdn;\n    }\n    DN newDN=this;\n    for (i=0; i < rdns.length; i++) {\n      newDN=new DN(this.schema,newDN,rdns[i]);\n    }\n    return newDN;\n  }\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new node.
# INFO:tensorflow:Inference results INPUT: @Override public void lifecycleEvent(LifecycleEvent event){\n  try {\n    host=(Host)event.getLifecycle();\n    if (host instanceof StandardHost) {\n      setCopyXML(((StandardHost)host).isCopyXML());\n      setDeployXML(((StandardHost)host).isDeployXML());\n      setUnpackWARs(((StandardHost)host).isUnpackWARs());\n      setContextClass(((StandardHost)host).getContextClass());\n    }\n  }\n catch (  ClassCastException e) {\n    log.error(sm.getString(\"hostConfig.cce\",event.getLifecycle()),e);\n    return;\n  }\n  if (event.getType().equals(Lifecycle.PERIODIC_EVENT)) {\n    check();\n  }\n else   if (event.getType().equals(Lifecycle.BEFORE_START_EVENT)) {\n    beforeStart();\n  }\n else   if (event.getType().equals(Lifecycle.START_EVENT)) {\n    start();\n  }\n else   if (event.getType().equals(Lifecycle.STOP_EVENT)) {\n    stop();\n  }\n}\n
# INFO:tensorflow:Inference results OUTPUT: This method is called when the activity is clicked.
# INFO:tensorflow:Inference results INPUT: private boolean isAllowedByIp(String ip) throws PolicyException {\n  boolean allowed=false;\n  long requestIp=stringToIp(ip);\n  Iterator ipValues=ipList.iterator();\n  while (ipValues.hasNext()) {\n    long startIp=((Long)ipValues.next()).longValue();\n    if (ipValues.hasNext()) {\n      long endIp=((Long)ipValues.next()).longValue();\n      if ((requestIp >= startIp) && (requestIp <= endIp)) {\n        allowed=true;\n        break;\n      }\n    }\n  }\n  if ((requestIp >= startIp) && (requestIp <= endIp)) {\n    allowed=true;\n  }\n  return allowed;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns true if the given string is valid.
# INFO:tensorflow:Inference results INPUT: protected void closeStartTag() throws SAXException {\n  if (m_elemContext.m_startTagOpen) {\n    try {\n      if (m_tracer != null)       super.fireStartElem(m_elemContext.m_elementName);\n      int nAttrs=m_attributes.getLength();\n      if (nAttrs > 0) {\n        processAttributes(m_writer,nAttrs);\n        m_attributes.clear();\n      }\n      m_writer.write(\'>\');\n    }\n catch (    IOException e) {\n      throw new SAXException(e);\n    }\n    if (m_CdataElems != null)     m_elemContext.m_isCdataSection=isCdataSection();\n    if (m_doIndent) {\n      m_isprevtext=false;\n      m_preserves.push(m_ispreserve);\n    }\n  }\n}\n
# INFO:tensorflow:Inference results OUTPUT: Close an element.
# INFO:tensorflow:Inference results INPUT: public void processInvite(RequestEvent requestEvent,ServerTransaction serverTransaction){\n  SipProvider sipProvider=(SipProvider)requestEvent.getSource();\n  Request request=requestEvent.getRequest();\n  try {\n    System.out.println(\"shootme: got an Invite sending Trying\");\n    Response response=messageFactory.createResponse(Response.TRYING,request);\n    ServerTransaction st=requestEvent.getServerTransaction();\n    if (st == null) {\n      st=sipProvider.getNewServerTransaction(request);\n    }\n    dialog=st.getDialog();\n    st.sendResponse(response);\n    this.okResponse=messageFactory.createResponse(Response.BUSY_HERE,request);\n    ToHeader toHeader=(ToHeader)okResponse.getHeader(ToHeader.NAME);\n    toHeader.setTag(\"4321\");\n    this.inviteTid=st;\n    this.inviteRequest=request;\n    new Timer().schedule(new MyTimerTask(this),100);\n  }\n catch (  Exception ex) {\n    ex.printStackTrace();\n    System.exit(0);\n  }\n}\n
# INFO:tensorflow:Inference results OUTPUT: Processes a message.
# INFO:tensorflow:Inference results INPUT: private void DrawViewsAtList(){\n  for (int i=0; i < listViews.size(); ++i) {\n    DetailView dvView=listViews.get(i);\n    View vChild=getChildAt(i);\n    int iL=dvView.getPoint().x * mUnitWidth;\n    int iT=dvView.getPoint().y * mUnitHeight;\n    int iR=iL + dvView.getWidthNum() * mUnitWidth;\n    int iB=iT + dvView.getHeightNum() * mUnitHeight;\n    vChild.setLeft(iL + mViewPadding);\n    vChild.setTop(iT + mViewPadding);\n    vChild.setRight(iR - mViewPadding);\n    vChild.setBottom(iB - mViewPadding);\n  }\n}\n
# INFO:tensorflow:Inference results OUTPUT: Provides a list of items in the view.
# INFO:tensorflow:Inference results INPUT: public void testDivideAndRemainderMathContextUP(){\n  String a=\"3736186567876876578956958765675671119238118911893939591735\";\n  int aScale=45;\n  String b=\"134432345432345748766876876723342238476237823787879183470\";\n  int bScale=70;\n  int precision=75;\n  RoundingMode rm=RoundingMode.UP;\n  MathContext mc=new MathContext(precision,rm);\n  String res=\"277923185514690367474770683\";\n  int resScale=0;\n  String rem=\"1.3032693871288309587558885943391070087960319452465789990E-15\";\n  int remScale=70;\n  BigDecimal aNumber=new BigDecimal(new BigInteger(a),aScale);\n  BigDecimal bNumber=new BigDecimal(new BigInteger(b),bScale);\n  BigDecimal result[]=aNumber.divideAndRemainder(bNumber,mc);\n  assertEquals(\"incorrect quotient value\",res,result[0].toString());\n  assertEquals(\"incorrect quotient scale\",resScale,result[0].scale());\n  assertEquals(\"incorrect remainder value\",rem,result[1].toString());\n  assertEquals(\"incorrect remainder scale\",remScale,result[1].scale());\n}\n
# INFO:tensorflow:Inference results OUTPUT: Divide.
# INFO:tensorflow:Inference results INPUT: public void processAck(RequestEvent requestEvent,ServerTransaction serverTransaction){\n  SipProvider sipProvider=(SipProvider)requestEvent.getSource();\n  try {\n    logger.info(\"shootme: got an ACK \" + requestEvent.getRequest());\n    TestCase.assertTrue(\"dialog mismatch \",this.dialog == serverTransaction.getDialog());\n    int ackCount=((ApplicationData)dialog.getApplicationData()).ackCount;\n    if (ackCount == 1 && this.sendReInviteFlag) {\n      dialog=inviteTid.getDialog();\n      this.sendReInvite(sipProvider);\n    }\n else     ((ApplicationData)dialog.getApplicationData()).ackCount++;\n  }\n catch (  Exception ex) {\n    String s=\"Unexpected error\";\n    logger.error(s,ex);\n    TestCase.fail(s);\n  }\n}\n
# INFO:tensorflow:Inference results OUTPUT: Processes a message.
# INFO:tensorflow:Decoding batch 1
# INFO:tensorflow:Inference results INPUT: public void addMember(PersistentObject member) throws UMSException {\n  DN userDN=DN.valueOf(member.getGuid().getDn());\n  LDAPUrl memberUrl=getUrl();\n  DN memberDN=memberUrl.getName();\n  if (!userDN.isInScopeOf(memberDN,SearchScope.WHOLE_SUBTREE)) {\n    String args[]=new String[2];\n    args[0]=userDN.toString();\n    args[1]=memberUrl.toString();\n    throw new UMSException(i18n.getString(IUMSConstants.USER_NOT_IN_GROUP_SCOPE,args));\n  }\n else   if ((userDN.size() - memberDN.size()) > 1 && SearchScope.SINGLE_LEVEL.equals(memberUrl.getScope())) {\n    String args[]=new String[2];\n    args[0]=userDN.toString();\n    args[1]=memberUrl.toString();\n    throw new UMSException(i18n.getString(IUMSConstants.USER_NOT_IN_GROUP_SCOPE,args));\n  }\n  member.modify(new Attr(MEMBER_ATTR_NAME,this.getDN()),ModificationType.ADD);\n  member.save();\n}\n
# INFO:tensorflow:Inference results OUTPUT: Adds a new member to the given name.
# INFO:tensorflow:Inference results INPUT: private void addDITStructureRuleToSchemaFile(String schemaFile,DITStructureRule ditStructureRule,Set<ByteString> values,Set<DITStructureRule> addedDSRs,int depth) throws DirectoryException {\n  if (depth > 20) {\n    LocalizableMessage message=ERR_SCHEMA_MODIFY_CIRCULAR_REFERENCE_DSR.get(ditStructureRule.getNameOrRuleID());\n    throw new DirectoryException(ResultCode.UNWILLING_TO_PERFORM,message);\n  }\n  if (addedDSRs.contains(ditStructureRule)) {\n    return;\n  }\n  for (  DITStructureRule dsr : ditStructureRule.getSuperiorRules()) {\n    if (schemaFile.equals(getElementSchemaFile(dsr)) && !addedDSRs.contains(dsr)) {\n      addDITStructureRuleToSchemaFile(schemaFile,dsr,values,addedDSRs,depth + 1);\n    }\n  }\n  values.add(ByteString.valueOfUtf8(ditStructureRule.toString()));\n  addedDSRs.add(ditStructureRule);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Adds a new extension to the given file.
# INFO:tensorflow:Inference results INPUT: public void appendBits(int value,int numBits){\n  if (numBits < 0 || numBits > 32) {\n    throw new IllegalArgumentException(\"Num bits must be between 0 and 32\");\n  }\n  ensureCapacity(size + numBits);\n  for (int numBitsLeft=numBits; numBitsLeft > 0; numBitsLeft--) {\n    appendBit(((value >> (numBitsLeft - 1)) & 0x01) == 1);\n  }\n}\n
# INFO:tensorflow:Inference results OUTPUT: Appends the number of bits to the specified buffer.
# INFO:tensorflow:Inference results INPUT: public int doStartTag() throws JspException {\n  reset();\n  ViewBean vb=getParentViewBean();\n  java.util.Locale locale;\n  if (vb instanceof AuthViewBeanBase) {\n    AuthViewBeanBase ab=(AuthViewBeanBase)vb;\n    locale=ab.getRequestLocale();\n  }\n else {\n    locale=java.util.Locale.getDefault();\n  }\n  String rbName=(String)getValue(\"BundleName\");\n  String resKey=(String)getValue(\"ResourceKey\");\n  String resValue;\n  ResourceBundle rb=AMResourceBundleCache.getInstance().getResBundle(rbName,locale);\n  try {\n    resValue=rb.getString(resKey);\n  }\n catch (  MissingResourceException ex) {\n    resValue=resKey;\n  }\n  writeOutput(resValue);\n  return SKIP_BODY;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Launch the user.
# INFO:tensorflow:Inference results INPUT: @Override public void onResume(){\n  super.onResume();\n  Log.d(TAG,\"FMRadio onResume isGestureOpen = \" + isGestureOpen());\n  if (isFmRadioGestureSupport() && isGestureOpen()) {\n    resumePsensor();\n  }\n  Log.d(TAG,\"FmRadioActivity.onResume start\");\n  mIsActivityForeground=true;\n  if (null == mService) {\n    Log.d(TAG,\"service has not bind finished\");\n    mIsNeedShowNoAntennaDlg=false;\n    return;\n  }\n  updateMenuStatus();\n  updateDialogStatus();\n  if (!isRecordFileExist()) {\n    mButtonPlayback.setEnabled(false);\n  }\n  checkNoAntennaDialogInOnResume();\n  Log.d(TAG,\"FmRadioActivity.onResume end\");\n}\n
# INFO:tensorflow:Inference results OUTPUT: Called when the activity is clicked.
# INFO:tensorflow:Inference results INPUT: public static boolean isXML11ValidQName(String str){\n  final int colon=str.indexOf(\':\');\n  if (colon == 0 || colon == str.length() - 1) {\n    return false;\n  }\n  if (colon > 0) {\n    final String prefix=str.substring(0,colon);\n    final String localPart=str.substring(colon + 1);\n    return isXML11ValidNCName(prefix) && isXML11ValidNCName(localPart);\n  }\n else {\n    return isXML11ValidNCName(str);\n  }\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns true if the given string is a valid token.
# INFO:tensorflow:Inference results INPUT: public static List<MappedMember> findMethodParent(MappedClass owner,String name,String desc,boolean originalNames){\n  List<MappedMember> list=new ArrayList<MappedMember>();\n  for (  MappedClass interfaceClass : owner.getInterfaces()) {\n    MappedMember mm=findMethodInParentInclusive(interfaceClass,name,desc,originalNames);\n    if (mm != null) {\n      list.add(mm);\n    }\n  }\n  if (owner.getParent() != null) {\n    MappedMember mm=findMethodInParentInclusive(owner.getParent(),name,desc,originalNames);\n    if (mm != null) {\n      list.add(mm);\n    }\n  }\n  return list;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Finds the given class for the given class.
# INFO:tensorflow:Inference results INPUT: private Object[] ensureCapacity(int minCapacity){\n  if (tmp.length < minCapacity) {\n    int newSize=minCapacity;\n    newSize|=newSize >> 1;\n    newSize|=newSize >> 2;\n    newSize|=newSize >> 4;\n    newSize|=newSize >> 8;\n    newSize|=newSize >> 16;\n    newSize++;\n    if (newSize < 0)     newSize=minCapacity;\n else     newSize=Math.min(newSize,a.length >>> 1);\n    @SuppressWarnings({\"unchecked\",\"UnnecessaryLocalVariable\"}) Object[] newArray=new Object[newSize];\n    tmp=newArray;\n  }\n  return tmp;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Ensures that the specified array contains the same size.
# INFO:tensorflow:Inference results INPUT: public void testCertStore07() throws InvalidAlgorithmParameterException, NoSuchAlgorithmException {\n  if (!initParams()) {\n    return;\n  }\n  for (int i=0; i < dValid.length; i++) {\n    for (int j=1; j < invalidValues.length; j++) {\n      try {\n        CertStore.getInstance(dValid[i],dParams,invalidValues[j]);\n        fail(\"NoSuchProviderException must be thrown\");\n      }\n catch (      NoSuchProviderException e) {\n      }\n    }\n  }\n}\n
# INFO:tensorflow:Inference results OUTPUT: Test for <code>getinstance(provider provider)</code> method assertion: throws an exception.
# INFO:tensorflow:Inference results INPUT: public static Properties readPropertiesFile(final File file){\n  if (!file.exists()) {\n    JKIOUtil.logger.info(String.format(\"File %s doesnot exists , return empty map\",file.getName()));\n    return new Properties();\n  }\n  try {\n    InputStream in=new FileInputStream(file);\n    if (in != null) {\n      return readPropertiesStream(in);\n    }\n  }\n catch (  IOException e) {\n    JKExceptionUtil.handle(e);\n  }\n  return null;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Read a file.
# INFO:tensorflow:Inference results INPUT: public void onCreate(Bundle savedInstanceState){\n  Session session=Session.getActiveSession();\n  if (session == null) {\n    if (savedInstanceState != null) {\n      session=Session.restoreSession(activity,null,callback,savedInstanceState);\n    }\n    if (session == null) {\n      session=new Session(activity);\n    }\n    Session.setActiveSession(session);\n  }\n  if (savedInstanceState != null) {\n    String callIdString=savedInstanceState.getString(DIALOG_CALL_ID_SAVE_KEY);\n    if (callIdString != null) {\n      pendingFacebookDialogCallId=UUID.fromString(callIdString);\n    }\n    pendingFacebookDialogCallStore.restoreFromSavedInstanceState(savedInstanceState);\n  }\n}\n
# INFO:tensorflow:Inference results OUTPUT: Called when the activity is created.
# INFO:tensorflow:Inference results INPUT: private int normalizePort(int port,String host){\n  if ((1 <= port && port <= 65535) || (port == 0 && host == null)) {\n    return port;\n  }\n  throw new IllegalArgumentException(\"Invalid network port provided: \" + port + \" is not included in the [1, 65535] range.\");\n}\n
# INFO:tensorflow:Inference results OUTPUT: Normalizes the specified port.
# INFO:tensorflow:Inference results INPUT: int numCharCountBits(int ver){\n  if (1 <= ver && ver <= 9)   return numBitsCharCount[0];\n else   if (10 <= ver && ver <= 26)   return numBitsCharCount[1];\n else   if (27 <= ver && ver <= 40)   return numBitsCharCount[2];\n else   throw new IllegalArgumentException(\"Version number out of range\");\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns the number of bits in the given range.
# INFO:tensorflow:Inference results INPUT: private Socket createSSLOrBasicSocket(Socket startTLSSocket,SSLConnectionFactory sslConnectionFactory) throws SSLConnectionException, LDAPConnectionException {\n  if (sslConnectionFactory == null) {\n    return createSocket();\n  }\n else   if (!connectionOptions.useStartTLS()) {\n    return createSSLSocket(sslConnectionFactory);\n  }\n else {\n    try {\n      return sslConnectionFactory.createSocket(startTLSSocket,hostName,portNumber,true);\n    }\n catch (    IOException e) {\n      LocalizableMessage msg=INFO_RESULT_CLIENT_SIDE_CONNECT_ERROR.get();\n      throw new LDAPConnectionException(msg,CLIENT_SIDE_CONNECT_ERROR,null,e);\n    }\n  }\n}\n
# INFO:tensorflow:Inference results OUTPUT: Create a connection to a socket.
# ...
# INFO:tensorflow:Inference results OUTPUT: Constructs a new exception with the specified detail message.
# INFO:tensorflow:Inference results INPUT: protected boolean isRepaintingRoot(){\n  return isRepaintingRoot;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns <code>true</code>.
# INFO:tensorflow:Inference results INPUT: public java.lang.String toString(){\n  return toString(true,false);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns a string representation of this object.
# INFO:tensorflow:Inference results INPUT: public Leaves(TreeSpecies species,boolean isDecayable){\n  this(DEFAULT_TYPE,species,isDecayable);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new instance.
# INFO:tensorflow:Inference results INPUT: public Set keySet(){\n  return map.keySet();\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns a list of keys in the map.
# INFO:tensorflow:Inference results INPUT: @Override public void mark(int readlimit){\n}\n
# INFO:tensorflow:Inference results OUTPUT: Marks the current position.
# INFO:tensorflow:Inference results INPUT: public String toString(){\n  return attrSchema.toString();\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns a string representation of this object.
# INFO:tensorflow:Inference results INPUT: public Paragraph(String text){\n  this(new Text(text));\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs a <code>text</code>.
# INFO:tensorflow:Inference results INPUT: public void mouseWheelMoved(MouseWheelEvent e){\n  getHandler().mouseWheelMoved(e);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Invoked when the mouse is clicked.
# INFO:tensorflow:Inference results INPUT: private Object readResolve(){\n  return object;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Ensures that the given object is the same as an object.
# INFO:tensorflow:Inference results INPUT: public int count(){\n  return padstack_list.size();\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns the number of bytes in the specified array.
# INFO:tensorflow:Inference results INPUT: public boolean isResourceNameAllowed(){\n  return (isResourceNameAllowed);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Gets the value of the property.
# INFO:tensorflow:Inference results INPUT: public boolean isFileHidingEnabled(){\n  return useFileHiding;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns true if the current state is enabled.
# INFO:tensorflow:Inference results INPUT: public int plaline_len(){\n  return lines_list.size();\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns the number of bytes in the specified array.
# INFO:tensorflow:Inference results INPUT: public FrameBodyTSRC(byte textEncoding,String text){\n  super(textEncoding,text);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new instance of the given class.
# INFO:tensorflow:Inference results INPUT: public void printStackTrace(){\n  printStackTrace(new java.io.PrintWriter(System.err,true));\n}\n
# INFO:tensorflow:Inference results OUTPUT: Prints a message to the stack.
# INFO:tensorflow:Inference results INPUT: public boolean isBedSpawn(){\n  return this.isBedSpawn;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns <code>true</code>.
# INFO:tensorflow:Inference results INPUT: public boolean typesOnly(){\n  return typesOnly;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Gets the value of the type.
# INFO:tensorflow:Inference results INPUT: protected KeyListener createKeyListener(){\n  return getHandler();\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new listener.
# INFO:tensorflow:Inference results INPUT: public SQLSyntaxErrorException(String reason,Throwable cause){\n  super(reason,cause);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates an sqlexception object.
# INFO:tensorflow:Inference results INPUT: public boolean useStartTLS(){\n  return state.useStartTLS;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns true if the current state is enabled.
# INFO:tensorflow:Inference results INPUT: public LinkedHashMapEntry(final String... ldifLines){\n  this(Requests.newAddRequest(ldifLines));\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new <code>map</code> object.
# INFO:tensorflow:Inference results INPUT: public boolean isPreExternalInitializationSubcommand(){\n  return isSubcommand(PRE_EXTERNAL_INITIALIZATION_SUBCMD_NAME);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns true if the given plugin is not supported.
# INFO:tensorflow:Inference results INPUT: public boolean markSupported(){\n  return true;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns true if the given <code>listener</code> is <code>null</code> or <code>null</code>.
# INFO:tensorflow:Inference results INPUT: public ServerFaultException(final String messageCode){\n  super(null,messageCode,null);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs a new exception with the specified detail message.
# INFO:tensorflow:Inference results INPUT: public String toStringNoRevision(){\n  return Utils.joinAsString(\".\",major,minor,point);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns a string representation of the given string.
# INFO:tensorflow:Inference results INPUT: public TransactionUnavailableException(String message,Throwable cause){\n  super(message,cause);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs a new exception with the specified detail message and cause.
# INFO:tensorflow:Inference results INPUT: SessionTracker(Context context,Session.StatusCallback callback,Session session){\n  this(context,callback,session,true);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new connection.
# INFO:tensorflow:Inference results INPUT: public boolean hasPlayerCount(){\n  return fieldSetFlags()[0];\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns true if this field is a valid value.
# INFO:tensorflow:Decoding batch 14
# INFO:tensorflow:Inference results INPUT: public SQLIntegrityConstraintViolationException(String reason,Throwable cause){\n  super(reason,cause);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new <code>sqlexception</code> with the specified detail message.
# INFO:tensorflow:Inference results INPUT: public void removeTreeModelListener(TreeModelListener l){\n  listenerList.remove(TreeModelListener.class,l);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Removes a listener.
# INFO:tensorflow:Inference results INPUT: public void put(E e){\n  offer(e);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Adds a new element to the queue.
# INFO:tensorflow:Inference results INPUT: @Override protected void finalize(){\n  disconnect(DisconnectReason.OTHER,false,null);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Cleans up the connection.
# INFO:tensorflow:Inference results INPUT: public void startPrefixMapping(String prefix,String uri){\n}\n
# INFO:tensorflow:Inference results OUTPUT: <p>constructs a <code>illegalargumentexception</code> with a <code>null</code> or <code>null</code> or <code>null</code> or <code>null</code>.
# INFO:tensorflow:Inference results INPUT: public int position(){\n  return pos;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns the position of the current position.
# INFO:tensorflow:Inference results INPUT: public boolean isIgnoringCancelled(){\n  return ignoreCancelled;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns true if the current state is not enabled.
# INFO:tensorflow:Inference results INPUT: public boolean isIs(){\n  return is;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns true if this property is null.
# INFO:tensorflow:Inference results INPUT: public FSSAMLServiceViewBean(){\n  super(\"FSSAMLService\");\n  setDefaultDisplayURL(DEFAULT_DISPLAY_URL);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new instance.
# INFO:tensorflow:Inference results INPUT: public void resetTagDefinitions(){\n  mTagInfo=null;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Reset the cache.
# INFO:tensorflow:Inference results INPUT: public FactoryConfigurationError(java.lang.String msg){\n  super(msg);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new <code>reason</code> with the specified detail message.
# INFO:tensorflow:Inference results INPUT: public ExpressionException(String message){\n  super(message);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs a new exception with the specified detail message.
# INFO:tensorflow:Inference results INPUT: public GenericAgentProfileViewBean(){\n  super(\"GenericAgentProfile\");\n  setDefaultDisplayURL(DEFAULT_DISPLAY_URL);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new instance.
# INFO:tensorflow:Inference results INPUT: public Panel(LayoutManager layout){\n  setLayout(layout);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new panel.
# INFO:tensorflow:Inference results INPUT: public ObjectStack(int blocksize){\n  super(blocksize);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new <code>object</code> object.
# INFO:tensorflow:Inference results INPUT: public void resumeEncoding(){\n  this.suspendEncoding=false;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Resumes the output stream.
# INFO:tensorflow:Inference results INPUT: public XMLFilterImpl(XMLReader parent){\n  setParent(parent);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new instance.
# INFO:tensorflow:Inference results INPUT: public AttributeMissingException(Throwable cause){\n  super(cause);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs an instance with the specified detail message.
# INFO:tensorflow:Inference results INPUT: RhinoScriptEngine(RhinoScriptEngineFactory factory){\n  Reject.ifNull(factory);\n  this.factory=factory;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new instance of this class.
# INFO:tensorflow:Inference results INPUT: @Override public void flush(){\n}\n
# INFO:tensorflow:Inference results OUTPUT: Flushes the stream.
# INFO:tensorflow:Inference results INPUT: public void resetWait(){\n  spamChecker.resetSpamCheck(getWaitPeriod());\n}\n
# INFO:tensorflow:Inference results OUTPUT: Reset the state.
# INFO:tensorflow:Inference results INPUT: public SpinnerListModel(){\n  this(new Object[]{\"empty\"});\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs a new instance of the given class.
# INFO:tensorflow:Inference results INPUT: public IDMSecurityContextFactory(List<ScriptEntry> augmentationScripts){\n  this.augmentationScripts=augmentationScripts;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new instance of this class.
# INFO:tensorflow:Inference results INPUT: public PasswordPolicyException(String msg){\n  super(msg);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs a new exception with the specified detail message.
# INFO:tensorflow:Inference results INPUT: public void windowDeactivated(WindowEvent e){\n}\n
# INFO:tensorflow:Inference results OUTPUT: Called when the activity has been created.
# INFO:tensorflow:Inference results INPUT: public OpenDJLoggerFactory(){\n  loggerMap=new ConcurrentHashMap<>();\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new instance of this class.
# INFO:tensorflow:Inference results INPUT: boolean notificationEnabled(){\n  return notificationEnabledFlag;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Returns true if enabled.
# INFO:tensorflow:Inference results INPUT: public void notifyDataSetChanged(){\n  mDataSetObservable.notifyChanged();\n}\n
# INFO:tensorflow:Inference results OUTPUT: Notifies all listeners that have been changed.
# INFO:tensorflow:Inference results INPUT: public ExpectedImpl(T value){\n  this.value=Objects.requireNonNull(value);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new instance.
# INFO:tensorflow:Inference results INPUT: public UpgradeException(Throwable t){\n  super(t);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs a new exception with the specified detail message.
# INFO:tensorflow:Inference results INPUT: public KeyNotFoundException(Throwable ex){\n  super(ex);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs a new exception with the specified detail message.
# INFO:tensorflow:Inference results INPUT: public MapboxDirections(Builder builder){\n  this.builder=builder;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new <code>map</code> object.
# INFO:tensorflow:Decoding batch 15
# INFO:tensorflow:Inference results INPUT: public Point(Point p){\n  this(p.x,p.y);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Create a point.
# INFO:tensorflow:Inference results INPUT: public void logRequestInfo(HTTPRequestInfo requestInfo){\n}\n
# INFO:tensorflow:Inference results OUTPUT: Log a message.
# INFO:tensorflow:Inference results INPUT: public DERSequence(ASN1Encodable obj){\n  super(obj);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Create an object.
# INFO:tensorflow:Inference results INPUT: public AbstractMethodError(){\n  super();\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs a new <code>object</code> object.
# INFO:tensorflow:Inference results INPUT: public void fileNotFound(){\n}\n
# INFO:tensorflow:Inference results OUTPUT: This method is called when a file has been loaded.
# INFO:tensorflow:Inference results INPUT: public URIReferenceException(){\n  super();\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs a new exception with the specified detail message.
# INFO:tensorflow:Inference results INPUT: TokenEndpointAuthMethod(String type){\n  this.type=type;\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new instance.
# INFO:tensorflow:Inference results INPUT: public CharArrayWriter(){\n  this(32);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new <code>bufferedinputstream</code>.
# INFO:tensorflow:Inference results INPUT: public LineUnavailableException(){\n  super();\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs a new exception with the specified detail message.
# INFO:tensorflow:Inference results INPUT: void onDragEnter(){\n  mDragging=true;\n}\n
# INFO:tensorflow:Inference results OUTPUT: This method is called when an activity is created.
# INFO:tensorflow:Inference results INPUT: public Segment(){\n  this(null,0,0);\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs a new instance.
# INFO:tensorflow:Inference results INPUT: public GSSAPISASLMechanismHandler(){\n  super();\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new instance of this class.
# INFO:tensorflow:Inference results INPUT: void attachView(){\n  getPresenter().attachView(delegateCallback.getMvpView());\n}\n
# INFO:tensorflow:Inference results OUTPUT: Attaches the view to the view.
# INFO:tensorflow:Inference results INPUT: public HomesUserDatabase(){\n  super();\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new instance.
# INFO:tensorflow:Inference results INPUT: public MalformedURLException(){\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs a new <code>sqlexception</code> with the specified detail message.
# INFO:tensorflow:Inference results INPUT: protected ServerConstraintHandler(){\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new instance of this class.
# INFO:tensorflow:Inference results INPUT: public FeatureDescriptor(){\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs a new <code>meta</code> instance.
# INFO:tensorflow:Inference results INPUT: public NonReadableChannelException(){\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs a new <code>exception</code> with the specified detail message.
# INFO:tensorflow:Inference results INPUT: public SSOTokenProvider(){\n}\n
# INFO:tensorflow:Inference results OUTPUT: Constructs a new instance of the given <code>instance</code> instance.
# INFO:tensorflow:Inference results INPUT: private PrivilegeUtils(){\n}\n
# INFO:tensorflow:Inference results OUTPUT: Creates a new instance.
# INFO:tensorflow:Elapsed Time: 1034.93581
# INFO:tensorflow:Averaged Single Token Generation Time: 0.0101401 (time 1034.3726656 count 102008)
# INFO:tensorflow:Writing decodes into ./sampled_model.en
# INFO:tensorflow:Running decode hooks.
# INFO:tensorflow:Decode hooks done.
